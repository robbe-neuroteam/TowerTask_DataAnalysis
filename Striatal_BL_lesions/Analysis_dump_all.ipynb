# %%
import os
import copy
import pickle
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import similaritymeasures as sm
import matplotlib.patches as patches

from bisect import bisect
from scipy.stats import spearmanr
from matplotlib.gridspec import GridSpec
from processing_TowerCoordinates import *
from matplotlib.ticker import MaxNLocator
from processing_session_trajectory import *

plt.style.use('paper.mplstyle')

# %%
# defining data folder path and mice list

# path_to_data_folder is the path of the folder where you store the folders of your different mice.


path_to_data_folder = '/home/david/MyLocalData/Lesions'

# Analysing the entire group of mice
mice_to_analyse = ['MOUB6JRj748','MOUB6JRj749','MOUB6JRj750','MOUB6JRj751','MOUB6JRj752','MOU5465','MOU5468','MOU5500','MOU5501',
                   'MOUB6JRj753','MOUB6JRj755','MOUB6JRj756','MOU5289','MOU5291','MOU5413','MOU5415','MOU5471','MOU5496','MOU5498']

# Verify that all folders in mice_to_analyse are present in path_to_data_folder
missing_folders = [mouse for mouse in mice_to_analyse if not os.path.isdir(os.path.join(path_to_data_folder, mouse))]

if missing_folders:
    print("Missing mice folders:", missing_folders)
else:
    print("All mice folders are present in data folder.")

# Print the number of mice, the list of mice
print(f' {len(mice_to_analyse)} {"mice" if len(mice_to_analyse) > 1 else "mouse"} will be analysed\n')

# Select the number of sessions that will be analysed for each mice knowing the analysis starts with the first session (familiarisation)
first_and_last_session_indexes = [0,32]
# Select the number of sessions that will be in statistics
first_and_last_session_indexes_stats = [1,32]
# Out:
# All mice folders are present in data folder.
#  19 mice will be analysed

# %%
LESION_ANIMALS: list[str] = ['MOUB6JRj749','MOUB6JRj750','MOUB6JRj752','MOU5468','MOU5500',
                             'MOUB6JRj755','MOU5289','MOU5415','MOU5471','MOU5496']
SHAM_ANIMALS: list[str] = ['MOUB6JRj748','MOUB6JRj751','MOU5465','MOU5501',
                           'MOUB6JRj753','MOUB6JRj756','MOU5291','MOU5413','MOU5498']

groups = {
    "Lesion": LESION_ANIMALS,
    "Sham": SHAM_ANIMALS
}

# %% [markdown]
# ## Global parameters and functions

# %%
# Arena parameters

arena_coordinates_cm=[[2.5, 91.7], [90.3, 91.7], [90.3, 2.7], [2.5, 2.7]]

border_zone = [
    [(3, 3), (10, 3), (10, 90), (3, 90)],   # left
    [(3, 3), (3, 9.5), (92, 9.5), (92, 3)], # down
    [(84, 3), (92, 3), (92, 90), (84, 90)], # right
    [(3, 83), (3, 90), (92, 90), (92, 83)]  # up
]

trapeze_width = 30

# %%
# Global functions 
# exemple de commentaire JB

def cm2inch(value):
    return value / 2.54

def get_day_and_period(session_idx):
    day = session_idx // 2 + 1
    period = 'AM' if session_idx % 2 == 0 else 'PM'
    return day, period

def finding_mouse_rewarded_direction(folder_path_mouse_to_process, session_index):
    sessions_to_process = sorted([
        name for name in os.listdir(folder_path_mouse_to_process)
        if os.path.isdir(os.path.join(folder_path_mouse_to_process, name))
        and name.startswith('MOU')
    ])

    session_traj_df, session_turns_df, session_param_df = load_data(
        folder_path_mouse_to_process,
        sessions_to_process[session_index]
    )

    rewarded_direction_degrees = session_param_df["potentialRewardedDirections"][0]

    if session_param_df["allowRewardDelivery"][0]:
        if rewarded_direction_degrees == '[270]':
            rewarded_direction = 'CW'
        elif rewarded_direction_degrees == '[90]':
            rewarded_direction = 'CCW'
        elif rewarded_direction_degrees == '[90, 270]':
            rewarded_direction = 'both'
        else:
            print('ERROR: Unexpected rewarded direction value:', rewarded_direction_degrees)
            return None
    else:
        rewarded_direction = 'X'

    return rewarded_direction

def finding_mouse_timeout(folder_path_mouse_to_process, session_index):
    sessions_to_process = sorted([
        name for name in os.listdir(folder_path_mouse_to_process)
        if os.path.isdir(os.path.join(folder_path_mouse_to_process, name))
        and name.startswith('MOU')
    ])

    try:
        session_traj_df, session_turns_df, session_param_df = load_data(
            folder_path_mouse_to_process,
            sessions_to_process[session_index]
        )
    except Exception:
        return None

    if session_param_df is None:
        return None

    if 'Timeout' not in session_param_df.columns:
        return None

    timeout_value = session_param_df['Timeout'].iloc[0]

    if pd.isna(timeout_value):
        return None

    try:
        if isinstance(timeout_value, str):
            timeout_value = timeout_value.strip().replace('[', '').replace(']', '')
            if timeout_value == '':
                return None
            timeout_value = float(timeout_value)
        else:
            timeout_value = float(timeout_value)
    except Exception:
        return None

    if timeout_value.is_integer():
        timeout_value = int(timeout_value)

    return timeout_value

def add_timeout_background(ax, all_sessions, folder_path_reference_mouse, index_offset=0, session_threshold=21, alpha=0.18):
    timeout_colors = {
        0: 'lightgreen',
        5: '#ffe699',
        15: '#f4a3a3'
    }

    for session in all_sessions:
        if session < session_threshold:
            continue

        zero_based_session_index = session - 1

        timeout_value = finding_mouse_timeout(
            folder_path_reference_mouse,
            zero_based_session_index
        )

        if timeout_value not in timeout_colors:
            continue

        ax.axvspan(
            session + index_offset - 0.49,
            session + index_offset + 0.49,
            ymin=0,
            ymax=1,
            color=timeout_colors[timeout_value],
            alpha=alpha,
            zorder=-2,
            lw=0
        )

def filter_qts(qts):
    """
    Filtre les QTs comme dans Figure08:
    - enlève les QTs avec plus d'un trapeze switch
    - enlève les QTs dont la distance > 30 cm
    """
    filtered_qts = []

    for qt in qts:
        if qt[3]['num_trapezeswitch'] != 1:
            continue
        if qt[4]['epoch_distance'] > 30:
            continue
        filtered_qts.append(qt)

    return filtered_qts

# %%
# Plot functions

def get_group_summary(ax, mice_list, mouse_metric_persession, color, show_individual_mice, index_offset):
        all_session_indices = set()
        values_per_session = {}

        for mouse in mice_list:
            if mouse not in mouse_metric_persession:
                print(f"Mouse {mouse} not found in data. Skipping.")
                continue

            sessions = mouse_metric_persession[mouse]
            session_indices = [session[0] for session in sessions]
            values = [session[1] for session in sessions]

            if sum(np.isnan(x) for x in values) > 0:
                session_indices_array = np.array(session_indices)
                values_array = np.array(values)
                mask = ~np.isnan(values_array)
                session_indices = session_indices_array[mask]
                values = values_array[mask]

            if show_individual_mice and len(session_indices) > 0:
                ax.plot(
                    np.array(session_indices) + index_offset,
                    values,
                    marker='o',
                    linewidth=0.7,
                    markersize=1,
                    alpha=0.25,
                    color=color,
                    zorder=1
                )

            all_session_indices.update(session_indices)
            for session, value in sessions:
                if session not in values_per_session:
                    values_per_session[session] = []
                values_per_session[session].append(value)

        sorted_sessions = sorted(all_session_indices)

        median_values = []
        lower_quartile = []
        upper_quartile = []

        for session in sorted_sessions:
            session_values = values_per_session[session]
            median_values.append(np.nanmedian(session_values))
            lower_quartile.append(np.nanpercentile(session_values, 25))
            upper_quartile.append(np.nanpercentile(session_values, 75))

        return (
            np.array(sorted_sessions),
            np.array(median_values),
            np.array(lower_quartile),
            np.array(upper_quartile)
        )

def plot_learning_curves_two_groups(
    mouse_metric_persession,
    ax,
    group1_mice,
    group2_mice,
    group1_label='Sham',
    group2_label='Lesion',
    group1_color='black',
    group2_color='red',
    show_individual_mice=True,
    ylabel='',
    show_xlabel=True,
    tick_interval=1,
    index_offset=0,
    xlim=[None, None],
    ylim=None,
    show_fam=False,
    show_legend=True,
    legend_loc=(0.05, 0.9)
):

    s1, med1, q1_low, q1_high = get_group_summary(ax, group1_mice, mouse_metric_persession, group1_color, show_individual_mice, index_offset)
    s2, med2, q2_low, q2_high = get_group_summary(ax, group2_mice, mouse_metric_persession, group2_color, show_individual_mice, index_offset)

    if len(s1) > 0:
        ax.plot(s1 + index_offset, med1, color=group1_color, linewidth=2, zorder=10, alpha = 1,
                label=f'{group1_label} (n={len(group1_mice)})')
        ax.fill_between(s1 + index_offset,
                        q1_low,
                        q1_high,
                        color=group1_color,
                        alpha=0.2,
                        linewidth=0,
                        edgecolor='none',
                        antialiased=False
                    )

    if len(s2) > 0:
        ax.plot(s2 + index_offset, med2, color=group2_color, linewidth=2,zorder=10, alpha = 1,
                label=f'{group2_label} (n={len(group2_mice)})')
        ax.fill_between(s2 + index_offset,
                        q2_low,
                        q2_high,
                        color=group2_color,
                        alpha=0.2,
                        linewidth=0,
                        edgecolor='none',
                        antialiased=False
                    )

    if show_xlabel:
        ax.set_xlabel('Session Number', fontsize=7)

    ax.set_ylabel(ylabel, fontsize=7)
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))

    all_sessions = sorted(set(list(s1) + list(s2)))
    if len(all_sessions) > 0:
        max_index = max(all_sessions)
        ax.set_xticks(range(1 + index_offset, max_index + 1 + index_offset, tick_interval))

        # Use first mouse as reference to determine session parameters
        first_mouse = list(mouse_metric_persession.keys())[0]
        folder_path_first_mouse = os.path.join(path_to_data_folder, first_mouse)

        # Background color for timeout in depleting protocol only (from session 21)
        add_timeout_background(
            ax=ax,
            all_sessions=all_sessions,
            folder_path_reference_mouse=folder_path_first_mouse,
            index_offset=index_offset,
            session_threshold=21,
            alpha=0.18
        )

        for session in all_sessions:

            zero_based_session_index = session - 1

            rewarded_direction = finding_mouse_rewarded_direction(
                folder_path_first_mouse,
                zero_based_session_index
            )

            if rewarded_direction == 'X':
                band_color = "orange"

            elif rewarded_direction == "both":
                band_color = "#a875bc"

            elif rewarded_direction == "CW" :
                band_color = "blue"

            elif rewarded_direction == "CCW":
                band_color = "red"

            ax.axvspan(
                session + index_offset - 0.49,
                session + index_offset + 0.49,
                ymin=0.979,
                ymax=0.998,
                color=band_color,
                zorder=3,
                clip_on=False
            )

    if xlim is not None:
        ax.set_xlim(xlim)
    if ylim is not None:
        ax.set_ylim(ylim)

    ylimits = ax.get_ylim()
    rectangle_height = abs(ylimits[1] - ylimits[0])
    rect = patches.Rectangle((0.5, ylimits[0]), 2, rectangle_height, color='moccasin', alpha=1, lw=0, zorder=0)
    ax.add_patch(rect)

    if show_fam:
        ax.text(1.5, ylimits[1], "Fam.", fontsize=6, ha='center', va='bottom',
                fontweight='normal', color='orange', alpha=0.6, zorder=1000)

    if show_legend:
        ax.legend(frameon=False, loc=legend_loc)

# %%
# Pickle functions 

def get_pickle_jar_path(folder_path_mouse_to_process, session_to_process):
    session_folder = os.path.join(folder_path_mouse_to_process, session_to_process)
    pickle_jar_path = os.path.join(session_folder, "pickle_jar")
    os.makedirs(pickle_jar_path, exist_ok=True)
    return pickle_jar_path

def frechet_pickles_exist(pickle_jar_path, pickle_names):
    return all(
        os.path.exists(os.path.join(pickle_jar_path, filename))
        for filename in pickle_names.values()
    )

def save_frechet_pickles(pickle_jar_path, frechet_results,pickle_names):
    for key, value in frechet_results.items():
        filepath = os.path.join(pickle_jar_path, pickle_names[key])
        with open(filepath, "wb") as f:
            pickle.dump(value, f)

def load_frechet_pickles(pickle_jar_path, pickle_names):
    frechet_results = {}
    for key, filename in pickle_names.items():
        filepath = os.path.join(pickle_jar_path, filename)
        with open(filepath, "rb") as f:
            frechet_results[key] = pickle.load(f)
    return frechet_results

# %% [markdown]
# ### Total distance and average speed
# Data extraction

# %%
total_distance_m = {mouse: [] for mouse in mice_to_analyse}
average_speeds = {mouse: [] for mouse in mice_to_analyse}

for mouse in mice_to_analyse:

    folder_path_mouse_to_analyse = os.path.join(path_to_data_folder, mouse)
    
    sessions_to_analyse = sorted([
        name for name in os.listdir(folder_path_mouse_to_analyse)
        if os.path.isdir(os.path.join(folder_path_mouse_to_analyse, name))
        and name.startswith('MOU')
    ])
    
    sessions_to_analyse = sessions_to_analyse[first_and_last_session_indexes[0]:first_and_last_session_indexes[1]]

    for sessionindex, session_to_analyse in enumerate(sessions_to_analyse):
        
        output_pickle_filename = f"{session_to_analyse}_basic_processing_output.pickle"
        output_pickle_filepath = os.path.join(
            folder_path_mouse_to_analyse,
            session_to_analyse,
            output_pickle_filename
        )
        
        if not os.path.exists(output_pickle_filepath):
            total_distance_m[mouse].append([sessionindex + 1, np.nan])
            average_speeds[mouse].append([sessionindex + 1, np.nan])
            continue

        # Charger le pickle
        with open(output_pickle_filepath, "rb") as f:
            data = pickle.load(f)

        distances = data["distances"]
        total_distance = np.sum(distances)/100
        average_speed = data["average_speed"]

        total_distance_m[mouse].append([sessionindex + 1, total_distance])
        average_speeds[mouse].append([sessionindex + 1, average_speed])

# %% [markdown]
# Plot

# %%
fig = plt.figure(figsize=(cm2inch(12), cm2inch(15)), dpi=300, constrained_layout=False, facecolor='w')
gs = fig.add_gridspec(5, 1, hspace=0.45)

row1 = gs[4].subgridspec(1, 1)
ax_1 = plt.subplot(row1[0, 0])

plot_learning_curves_two_groups(
    mouse_metric_persession=total_distance_m,
    ax=ax_1,
    group1_mice=SHAM_ANIMALS,
    group2_mice=LESION_ANIMALS,
    group1_label='Sham',
    group2_label='Lesion',
    group1_color='black',
    group2_color='red',
    ylabel='Total distance (m)',
    show_xlabel=True,
    tick_interval=2,
    index_offset=0,
    xlim=[0.5, None],
    show_fam=True,
    legend_loc=(0.8, 1.1)
)

fig.tight_layout()
plt.subplots_adjust(left=0.15)
plt.show()
# Out:
# /tmp/ipykernel_11834/535951797.py:25: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %%
fig = plt.figure(figsize=(cm2inch(12), cm2inch(15)), dpi=300, constrained_layout=False, facecolor='w')
gs = fig.add_gridspec(5, 1, hspace=0.45)

row1 = gs[4].subgridspec(1, 1)
ax_1 = plt.subplot(row1[0, 0])

plot_learning_curves_two_groups(
    mouse_metric_persession=average_speeds,
    ax=ax_1,
    group1_mice=SHAM_ANIMALS,
    group2_mice=LESION_ANIMALS,
    group1_label='Sham',
    group2_label='Lesion',
    group1_color='black',
    group2_color='red',
    ylabel='Average speed (cm/s)',
    show_xlabel=True,
    tick_interval=2,
    index_offset=0,
    xlim=[0.5, None],
    show_fam=True,
    legend_loc=(0.8, 1.1)
)

fig.tight_layout()
plt.subplots_adjust(left=0.15)
plt.show()
# Out:
# /tmp/ipykernel_11834/4104281039.py:25: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ### Time spent in zones
# Function(s)

# %%
def calculate_time_in_zones(folder_path_mouse_to_analyse, session_to_analyse, border_zone, trapeze_width, time_start=None, time_end=None):
    
    """Calculate total time spent in border / trapeze / interior zones during a session."""

    pickle_file_path = os.path.join(folder_path_mouse_to_analyse, session_to_analyse, session_to_analyse + '_basic_processing_output.pickle')
    
    towers_coordinates = get_trapeze_and_tower_data(folder_path_mouse_to_analyse, session_to_analyse)[1]
    
    with open(pickle_file_path, 'rb') as f:
        session_data = pickle.load(f)
    
    smoothed_xpositions_cm = session_data['positions'][0]
    smoothed_ypositions_cm = session_data['positions'][1]
    times_videoFrames = session_data['timeofframes']

    all_trapezes_coordinates_cm = generate_trapeze_and_tower_coordinates(towers_coordinates, trapeze_width)[0]

    if time_start is None:
        time_start = times_videoFrames[0]
    if time_end is None:
        time_end = times_videoFrames[-1]

    start_idx = np.searchsorted(times_videoFrames, time_start)
    end_idx = np.searchsorted(times_videoFrames, time_end)

    selected_xpositions = smoothed_xpositions_cm[start_idx:end_idx]
    selected_ypositions = smoothed_ypositions_cm[start_idx:end_idx]
    selected_time = times_videoFrames[start_idx:end_idx]

    border_polygons = [
        mpath.Path(border_zone[0]),
        mpath.Path(border_zone[1]),
        mpath.Path(border_zone[2]),
        mpath.Path(border_zone[3])
    ]
    
    trapeze_polygons = []
    for tower, trapezes in all_trapezes_coordinates_cm.items():
        for trapeze, coords in trapezes.items():
            trapeze_polygons.append(mpath.Path(coords))
    
    inner_setup_size = (10, 9.5, 84, 83)
    interior_polygon = mpath.Path([
        (inner_setup_size[0], inner_setup_size[1]),
        (inner_setup_size[0], inner_setup_size[3]),
        (inner_setup_size[2], inner_setup_size[3]),
        (inner_setup_size[2], inner_setup_size[1])
    ])
    
    time_in_border = 0
    time_in_trapeze = 0
    time_in_interior = 0
  
    for i in range(len(selected_xpositions) - 1):
        point_start = np.array([selected_xpositions[i], selected_ypositions[i]])
        dt = selected_time[i+1] - selected_time[i]

        if any(polygon.contains_point(point_start) for polygon in border_polygons):
            time_in_border += dt
        elif any(polygon.contains_point(point_start) for polygon in trapeze_polygons):
            time_in_trapeze += dt
        elif interior_polygon.contains_point(point_start):
            time_in_interior += dt

    time_spent_in_zones = {
        'border': round(time_in_border, 2),
        'trapeze': round(time_in_trapeze, 2),
        'interior': round(time_in_interior, 2)
    }

    return time_spent_in_zones

# %% [markdown]
# Data extraction

# %%
# Choosing start and end times (s) of chunks of trajectory
time_start_start = 15
time_end_start = 195
time_start_end = 540
time_end_end = 720

mouse_timediff_trapezevsborder = {mouse: [] for mouse in mice_to_analyse}
mouse_timediff_trapezevsborder_start = {mouse: [] for mouse in mice_to_analyse}
mouse_timediff_trapezevsborder_end = {mouse: [] for mouse in mice_to_analyse}

for mouse in mice_to_analyse:

    folder_path_mouse_to_analyse = os.path.join(path_to_data_folder, mouse)
    
    sessions_to_analyse = sorted([
        name for name in os.listdir(folder_path_mouse_to_analyse)
        if os.path.isdir(os.path.join(folder_path_mouse_to_analyse, name))
        and name.startswith('MOU')
    ])
    
    sessions_to_analyse = sessions_to_analyse[first_and_last_session_indexes[0]:first_and_last_session_indexes[1]]

    for sessionindex, session_to_analyse in enumerate(sessions_to_analyse):
        
        output_pickle_filename = f"{session_to_analyse}_basic_processing_output.pickle"
        output_pickle_filepath = os.path.join(
            folder_path_mouse_to_analyse,
            session_to_analyse,
            output_pickle_filename
        )
        
        if not os.path.exists(output_pickle_filepath):
            mouse_timediff_trapezevsborder[mouse].append([sessionindex + 1, np.nan])
            mouse_timediff_trapezevsborder_start[mouse].append([sessionindex + 1, np.nan])
            mouse_timediff_trapezevsborder_end[mouse].append([sessionindex + 1, np.nan])
            continue

        # Charger le pickle
        with open(output_pickle_filepath, "rb") as f:
            data = pickle.load(f)

        # Session entière (déjà calculée dans le pickle)
        time_spentinzones = data["time_in_zones"]

        mouse_timediff_trapezevsborder[mouse].append([
            sessionindex + 1,
            time_spentinzones['trapeze'] - time_spentinzones['border']
        ])

        # Début de session
        time_spentinzones_start = calculate_time_in_zones(
            folder_path_mouse_to_analyse,
            session_to_analyse,
            border_zone,
            trapeze_width=trapeze_width,
            time_start=time_start_start,
            time_end=time_end_start
        )
        
        mouse_timediff_trapezevsborder_start[mouse].append([
            sessionindex + 1,
            time_spentinzones_start['trapeze'] - time_spentinzones_start['border']
        ])

        # Fin de session
        time_spentinzones_end = calculate_time_in_zones(
            folder_path_mouse_to_analyse,
            session_to_analyse,
            border_zone,
            trapeze_width=trapeze_width,
            time_start=time_start_end,
            time_end=time_end_end
        )
        
        mouse_timediff_trapezevsborder_end[mouse].append([
            sessionindex + 1,
            time_spentinzones_end['trapeze'] - time_spentinzones_end['border']
        ])

# %% [markdown]
# Plot

# %%
fig = plt.figure(figsize=(cm2inch(12), cm2inch(15)), dpi=300, constrained_layout=False, facecolor='w')
gs = fig.add_gridspec(5, 1, hspace=0.45)

row1 = gs[4].subgridspec(1, 1)
ax_1 = plt.subplot(row1[0, 0])

plot_learning_curves_two_groups(
    mouse_metric_persession=mouse_timediff_trapezevsborder,
    ax=ax_1,
    group1_mice=SHAM_ANIMALS,
    group2_mice=LESION_ANIMALS,
    group1_label='Sham',
    group2_label='Lesion',
    group1_color='black',
    group2_color='red',
    ylabel='Trapeze - Border (s)',
    show_xlabel=True,
    tick_interval=2,
    index_offset=0,
    xlim=[0.5, None],
    show_fam=True,
    legend_loc=(0.5, 0.05)
)

fig.tight_layout()
plt.subplots_adjust(left=0.15)
plt.show()
# Out:
# /tmp/ipykernel_11834/1822369856.py:25: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ### Exploitation score
#
# Function(s)

# %%
def order_runs(all_epochs):
    ordered_all_runs = []
    ordered_all_runs_frames = []

    for k in all_epochs.keys():
        if k != 'immobility':
            for i in range(len(all_epochs[k])):
                ordered_all_runs.append(all_epochs[k][i])
                ordered_all_runs_frames.append(all_epochs[k][i][0])

    ordered_all_runs_frames = sorted(ordered_all_runs_frames, key=lambda x: x[0])
    ordered_all_runs = sorted(ordered_all_runs, key=lambda x: x[0])

    return ordered_all_runs, ordered_all_runs_frames

def define_visits(all_epochs):
    visits = []
    n = -1

    runs_around_tower = all_epochs['run_around_tower']

    temp_all_epochs = all_epochs.copy()
    temp_all_epochs['run_around_tower'] = runs_around_tower

    ordered_all_runs, ordered_all_runs_frames = order_runs(temp_all_epochs)

    for i, run_around_tower in enumerate(runs_around_tower):
        is_good_turn = run_around_tower[3]['Rewarded']
        max_rewards = run_around_tower[3]['max_rewards']

        ordered_idx = ordered_all_runs_frames.index(run_around_tower[0])

        departure, arrival = (
            [ordered_all_runs[ordered_idx - 1][1][0], ordered_all_runs[ordered_idx - 1][2][0]]
            if ordered_idx != 0 else ['', '']
        )

        previous_run_not_a_turn = (departure != arrival) or len(visits) == 0
        previous_run_started_elsewhere = (
            ordered_all_runs[ordered_idx - 1][1][0] != ordered_all_runs[ordered_idx][1][0]
        ) if ordered_idx != 0 else True

        if previous_run_not_a_turn or previous_run_started_elsewhere:
            n += 1
            visits.append({})

            visits[n]['turns'] = 1
            visits[n]['rewarded_turns'] = int(is_good_turn)
            visits[n]['max_reward'] = max_rewards
            visits[n]['patch'] = run_around_tower[1][0]
            visits[n]['visit_time'] = run_around_tower[4]['epoch_time']
            visits[n]['turns_time'] = [run_around_tower[4]['epoch_time']]
            visits[n]['turns_duration'] = [run_around_tower[4]['epoch_duration']]
        else:
            visits[n]['rewarded_turns'] += int(is_good_turn)
            visits[n]['turns'] += 1
            visits[n]['turns_time'] = visits[n]['turns_time'] + [run_around_tower[4]['epoch_time']]
            visits[n]['turns_duration'] = visits[n]['turns_duration'] + [run_around_tower[4]['epoch_duration']]

    return visits

def define_csv_visits(df):
    n = -1
    visits = []

    for i in range(len(df)):
        previous_transition_in_other_patch = df.currentPatch[i] != df.currentPatch[i - 1] if i > 0 else True
        previous_cumulated_rewards_higher = df.nberOfConsecRewards[i] < df.nberOfConsecRewards[i - 1] if i > 0 else True
        previous_cumulated_rewards_zero = df.nberOfConsecRewards[i - 1] == 0 if i > 0 else True
        left_tower_after_previous_transition = previous_cumulated_rewards_higher and previous_cumulated_rewards_zero

        if previous_transition_in_other_patch or left_tower_after_previous_transition:
            n += 1
            visits.append({})

            visits[n]['transitions'] = 1
            visits[n]['rewarded_transitions'] = int(df.Rewarded[i])
            visits[n]['cumulated_rewards'] = df.nberOfConsecRewards[i]
            visits[n]['max_reward'] = df.maxNberOfConsecRewards[i]
            visits[n]['patch'] = df.currentPatch[i]
            visits[n]['first_transition_time'] = df.time[i]
            visits[n]['transitions_time'] = [df.time[i]]
            visits[n]['transitions_reward_status'] = [df.Rewarded[i]]
        else:
            visits[n]['transitions'] += 1
            visits[n]['rewarded_transitions'] += int(df.Rewarded[i])
            visits[n]['cumulated_rewards'] = df.nberOfConsecRewards[i]
            visits[n]['transitions_time'] = visits[n]['transitions_time'] + [df.time[i]]
            visits[n]['transitions_reward_status'] = visits[n]['transitions_reward_status'] + [df.Rewarded[i]]

    return visits

def find_rewarded_csv_visit(visits):
    return [visit for visit in visits if visit['rewarded_transitions'] > 0]

def check_is_transition_in_pickle_visit(csv_visit, pickle_visit):
    for transition_time in csv_visit['transitions_time']:
        for i in range(len(pickle_visit['turns_time'])):
            turn_start_time = pickle_visit['turns_time'][i]
            turn_end_time = pickle_visit['turns_time'][i] + pickle_visit['turns_duration'][i]

            if turn_start_time <= transition_time <= turn_end_time:
                return True

    return False

def pair_csv_pickle_visits(csv_visits, pickle_visits):
    
    kept_visits = []

    pickle_visits_temp = copy.deepcopy(pickle_visits)
    csv_visits_temp = copy.deepcopy(csv_visits)

    while len(pickle_visits_temp) > 0:
        pickle_visit = pickle_visits_temp[0]

        for i, csv_visit in enumerate(csv_visits_temp):
            is_transition_in_pickle_visit = check_is_transition_in_pickle_visit(csv_visit, pickle_visit)

            if is_transition_in_pickle_visit:
                kept_visits.append(csv_visit)
                pickle_visits_temp.pop(0)
                break

    return kept_visits

# %% [markdown]
# Data extraction

# %%
mouse_mean_turns_per_rewarded_visit = {mouse: [] for mouse in mice_to_analyse}

for mouse in mice_to_analyse:
    folder_path_mouse_to_analyse = os.path.join(path_to_data_folder, mouse)

    sessions_to_analyse = sorted([
        name for name in os.listdir(folder_path_mouse_to_analyse)
        if os.path.isdir(os.path.join(folder_path_mouse_to_analyse, name))
        and name.startswith('MOU')
    ])

    sessions_to_analyse = sessions_to_analyse[first_and_last_session_indexes[0]:first_and_last_session_indexes[1]]

    print(f'Mouse {mouse}. {len(sessions_to_analyse)} sessions')

    for session_index, session_to_analyse in enumerate(sessions_to_analyse):
        output_pickle_filename = f"{session_to_analyse}_basic_processing_output.pickle"
        output_pickle_filepath = os.path.join(
            folder_path_mouse_to_analyse,
            session_to_analyse,
            output_pickle_filename
        )

        turns_csv_path = os.path.join(
            folder_path_mouse_to_analyse,
            session_to_analyse,
            session_to_analyse + '_turnsinfo.csv'
        )

        if not os.path.exists(output_pickle_filepath) or not os.path.exists(turns_csv_path):
            mouse_mean_turns_per_rewarded_visit[mouse].append([session_index + 1, np.nan])
            continue

        with open(output_pickle_filepath, 'rb') as file:
            session_data = pickle.load(file)

        turns_df = pd.read_csv(turns_csv_path)

        pickle_visits = define_visits(session_data['all_epochs'])
        rewarded_pickle_visits = [v for v in pickle_visits if v['rewarded_turns'] > 0]

        csv_visits = define_csv_visits(turns_df)
        rewarded_csv_visits = find_rewarded_csv_visit(csv_visits)
        paired_rewarded_csv_visits = pair_csv_pickle_visits(rewarded_csv_visits, rewarded_pickle_visits)

        transitions_list = []

        for csv_visit, pickle_visit in zip(paired_rewarded_csv_visits, rewarded_pickle_visits):
            transitions = csv_visit['transitions']

            if csv_visit['transitions_time'][-1] > (
                pickle_visit['turns_time'][-1] + pickle_visit['turns_duration'][-1]
            ):
                transitions -= 1

            transitions_list.append(transitions)

        mean_turns_per_rewarded_visit = np.nanmean(transitions_list) if len(transitions_list) > 0 else np.nan

        if session_index >= 2:
            mouse_mean_turns_per_rewarded_visit[mouse].append([session_index + 1, mean_turns_per_rewarded_visit])
        else:
            mouse_mean_turns_per_rewarded_visit[mouse].append([session_index + 1, np.nan])
# Out:
# Mouse MOUB6JRj748. 32 sessions
# Mouse MOUB6JRj749. 32 sessions
# Mouse MOUB6JRj750. 32 sessions
# Mouse MOUB6JRj751. 32 sessions
# Mouse MOUB6JRj752. 32 sessions
# Mouse MOU5465. 31 sessions
# Mouse MOU5468. 31 sessions
# Mouse MOU5500. 14 sessions
# Mouse MOU5501. 14 sessions
# Mouse MOUB6JRj753. 32 sessions
# Mouse MOUB6JRj755. 32 sessions
# Mouse MOUB6JRj756. 32 sessions
# Mouse MOU5289. 32 sessions
# Mouse MOU5291. 32 sessions
# Mouse MOU5413. 32 sessions
# Mouse MOU5415. 32 sessions
# Mouse MOU5471. 31 sessions
# Mouse MOU5496. 14 sessions
# Mouse MOU5498. 14 sessions

# %%
fig = plt.figure(figsize=(cm2inch(12), cm2inch(8)), dpi=300, facecolor='w')
ax = fig.add_subplot(111)

ax.axhline(
    8,
    linestyle='--',
    color='gray',
    linewidth=1,
    label='Mean maximum available reward'
)

ax.axhspan(
    4, 12,
    xmin=0.06,
    color='lightgray',
    alpha=0.5,
    linewidth=0,
    zorder=-np.inf,
    label='Interval of possible maximum available reward'
)

plot_learning_curves_two_groups(
    mouse_metric_persession=mouse_mean_turns_per_rewarded_visit,
    ax=ax,
    group1_mice=SHAM_ANIMALS,
    group2_mice=LESION_ANIMALS,
    group1_label='Sham',
    group2_label='Lesion',
    group1_color='black',
    group2_color='red',
    ylabel='Rewarded visits\nexploitation score',
    show_xlabel=True,
    tick_interval=2,
    index_offset=0,
    xlim=[0.5, None],
    ylim=[0, 12],
    show_fam=True,
    legend_loc=(0.01, 1.1)
)

ax.set_yticks(range(0, 30, 2))

fig.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_11834/12045649.py:43: UserWarning: The figure layout has changed to tight
#   fig.tight_layout()

# %% [markdown]
# ### Fréchet distance
# Function(s)

# %%
def towers_coordinates_as_dictionnary(towers_coordinates_cm):
    """
    Convertit les coordonnées des tours en dictionnaire structuré
    avec les coins explicitement nommés.
    """

    towers_coordinates_as_dict = {}
    corner_names = ['NW', 'NE', 'SE', 'SW']

    for tower, coordinates in towers_coordinates_cm.items():
        towers_coordinates_as_dict[tower] = {
            corner_names[i]: coord for i, coord in enumerate(coordinates)
        }

    return towers_coordinates_as_dict

def get_tower_and_corner(run_around_tower):
    """
    Détermine le nom de la tour et le coin concerné à partir
    des infos de départ/arrivée du QT.
    """

    tower_name = run_around_tower[1][0]
    start_trapeze = run_around_tower[1][1]
    end_trapeze = run_around_tower[2][1]

    if start_trapeze == 'W' and end_trapeze == 'S':
        corner = 'SW'
    elif start_trapeze == 'S' and end_trapeze == 'E':
        corner = 'SE'
    elif start_trapeze == 'E' and end_trapeze == 'N':
        corner = 'NE'
    elif start_trapeze == 'N' and end_trapeze == 'W':
        corner = 'NW'
    elif start_trapeze == 'W' and end_trapeze == 'N':
        corner = 'NW'
    elif start_trapeze == 'N' and end_trapeze == 'E':
        corner = 'NE'
    elif start_trapeze == 'E' and end_trapeze == 'S':
        corner = 'SE'
    elif start_trapeze == 'S' and end_trapeze == 'W':
        corner = 'SW'
    else:
        corner = None

    return tower_name, corner

def rotate_sw_trajectory_90_ccw(trajectory):
    """
    Rotation 90° sens anti-horaire.
    """
    rotation_matrix = np.array([[0, -1], [1, 0]])
    return rotation_matrix @ trajectory

def rotate_nw_trajectory_180_ccw(trajectory):
    """
    Rotation 180° sens anti-horaire.
    """
    return -trajectory

def rotate_ne_trajectory_270_ccw(trajectory):
    """
    Rotation 270° sens anti-horaire.
    """
    rotation_matrix = np.array([[0, 1], [-1, 0]])
    return rotation_matrix @ trajectory

def align_cw_ccw_trajectory(trajectory, direction, flip_axis='x'):
    """
    Align CCW quarter-turns onto the CW reference frame.
    
    Parameters
    ----------
    trajectory : np.ndarray
        2 x N array
    direction : str
        'CW' or 'CCW'
    flip_axis : str
        'x' or 'y'. Axis used to mirror CCW trajectories.
    
    Returns
    -------
    np.ndarray
        Aligned trajectory
    """
    aligned_trajectory = trajectory.copy()

    if direction == 'CCW':
        if flip_axis == 'x':
            aligned_trajectory[0, :] = -aligned_trajectory[0, :]
        elif flip_axis == 'y':
            aligned_trajectory[1, :] = -aligned_trajectory[1, :]
        else:
            raise ValueError("flip_axis must be 'x' or 'y'")

    return aligned_trajectory

def compute_frechet_distances(runs_list):
    """
    Calcule la distance de Fréchet pour toutes les paires de trajectoires.
    Les trajectoires doivent être au format (2, N).
    Retourne la liste des distances.
    """

    frechet_distances_list = []

    for i in range(len(runs_list)):
        traj_points_a = np.transpose(runs_list[i])

        for j in range(i + 1, len(runs_list)):
            traj_points_b = np.transpose(runs_list[j])
            frechet_distance = sm.frechet_dist(traj_points_a, traj_points_b)
            frechet_distances_list.append(frechet_distance)

    return frechet_distances_list

def align_qt_trajectory(this_trajectory, tower_name, corner, direction,
                        towers_coordinates_as_dict,
                        align_direction=False, flip_axis='x'):
    """
    Align a QT trajectory:
    1) translate to tower corner
    2) rotate depending on corner
    3) optionally mirror CCW onto CW
    
    Parameters
    ----------
    this_trajectory : np.ndarray
        2 x N trajectory
    tower_name : str
    corner : str
    direction : str
        'CW' or 'CCW'
    towers_coordinates_as_dict : dict
    align_direction : bool
        If True, CCW trajectories are mirrored onto CW reference frame
    flip_axis : str
        'x' or 'y'
    
    Returns
    -------
    np.ndarray
        aligned trajectory
    """
    aligned_trajectory = this_trajectory.copy()

    this_corner_coordinates = towers_coordinates_as_dict[tower_name][corner]

    # Translation
    aligned_trajectory[0, :] -= this_corner_coordinates[0]
    aligned_trajectory[1, :] -= this_corner_coordinates[1]

    # Rotation depending on corner
    if corner == 'SW':
        aligned_trajectory = rotate_sw_trajectory_90_ccw(aligned_trajectory)
    elif corner == 'NW':
        aligned_trajectory = rotate_nw_trajectory_180_ccw(aligned_trajectory)
    elif corner == 'NE':
        aligned_trajectory = rotate_ne_trajectory_270_ccw(aligned_trajectory)
    # if corner == 'SE': do nothing

    # Optional CW/CCW alignment
    if align_direction:
        aligned_trajectory = align_cw_ccw_trajectory(
            aligned_trajectory,
            direction=direction,
            flip_axis=flip_axis
        )

    return aligned_trajectory

def compute_session_frechet(trajectories, minimum_number_of_qts=5):
    if len(trajectories) >= minimum_number_of_qts:
        return np.nanmedian(compute_frechet_distances(trajectories))
    return np.nan

def compute_frechet_for_one_session(folder_path_mouse_to_process, session_to_process, minimum_number_of_qts=5):
    
    output_pickle_filename = f"{session_to_process}_basic_processing_output.pickle"
    output_pickle_filepath = os.path.join(
        folder_path_mouse_to_process,
        session_to_process,
        output_pickle_filename
    )

    if not os.path.exists(output_pickle_filepath):
        return {
            "rewarded_frechet": np.nan,
            "unrewarded_frechet": np.nan,
            "cw_frechet": np.nan,
            "ccw_frechet": np.nan,
            "cw_rew_frechet": np.nan,
            "ccw_rew_frechet": np.nan,
            "cw_unrew_frechet": np.nan,
            "ccw_unrew_frechet": np.nan,
        }

    with open(output_pickle_filepath, "rb") as file:
        session_data = pickle.load(file)

    runs_around_tower = filter_qts(copy.deepcopy(session_data["all_epochs"]["run_around_tower"]))
    positions = np.array(session_data["positions"])

    towers_coordinates_cm = session_data["towers_coordinates_cm"]
    towers_coordinates_as_dict = towers_coordinates_as_dictionnary(towers_coordinates_cm)

    rewarded_trajectories = []
    unrewarded_trajectories = []
    cw_trajectories = []
    ccw_trajectories = []
    cw_rewarded_trajectories = []
    ccw_rewarded_trajectories = []
    cw_unrewarded_trajectories = []
    ccw_unrewarded_trajectories = []

    for run_around_tower in runs_around_tower:

        if run_around_tower[3]["num_trapezeswitch"] != 1:
            continue

        rewarded = run_around_tower[3]["Rewarded"]
        direction = run_around_tower[3]["direction"]

        if direction not in ["CW", "CCW"]:
            continue

        tower_name, corner = get_tower_and_corner(run_around_tower)

        if tower_name not in towers_coordinates_as_dict:
            continue

        if corner not in towers_coordinates_as_dict[tower_name]:
            continue

        start_idx, end_idx = run_around_tower[0]
        this_trajectory = positions[:, start_idx:end_idx].copy()

        aligned_for_reward = align_qt_trajectory(
            this_trajectory=this_trajectory,
            tower_name=tower_name,
            corner=corner,
            direction=direction,
            towers_coordinates_as_dict=towers_coordinates_as_dict,
            align_direction=True,
            flip_axis="x"
        )

        aligned_for_direction = align_qt_trajectory(
            this_trajectory=this_trajectory,
            tower_name=tower_name,
            corner=corner,
            direction=direction,
            towers_coordinates_as_dict=towers_coordinates_as_dict,
            align_direction=False
        )

        if rewarded:
            rewarded_trajectories.append(aligned_for_reward)
        else:
            unrewarded_trajectories.append(aligned_for_reward)

        if direction == "CW":
            cw_trajectories.append(aligned_for_direction)
            if rewarded:
                cw_rewarded_trajectories.append(aligned_for_direction)
            else:
                cw_unrewarded_trajectories.append(aligned_for_direction)

        elif direction == "CCW":
            ccw_trajectories.append(aligned_for_direction)
            if rewarded:
                ccw_rewarded_trajectories.append(aligned_for_direction)
            else:
                ccw_unrewarded_trajectories.append(aligned_for_direction)

    frechet_results = {
        "rewarded_frechet": compute_session_frechet(rewarded_trajectories, minimum_number_of_qts),
        "unrewarded_frechet": compute_session_frechet(unrewarded_trajectories, minimum_number_of_qts),
        "cw_frechet": compute_session_frechet(cw_trajectories, minimum_number_of_qts),
        "ccw_frechet": compute_session_frechet(ccw_trajectories, minimum_number_of_qts),
        "cw_rew_frechet": compute_session_frechet(cw_rewarded_trajectories, minimum_number_of_qts),
        "ccw_rew_frechet": compute_session_frechet(ccw_rewarded_trajectories, minimum_number_of_qts),
        "cw_unrew_frechet": compute_session_frechet(cw_unrewarded_trajectories, minimum_number_of_qts),
        "ccw_unrew_frechet": compute_session_frechet(ccw_unrewarded_trajectories, minimum_number_of_qts),
    }

    return frechet_results

# %% [markdown]
# Data extraction

# %%
FRECHET_PICKLE_NAMES = {
    "ccw_unrew_frechet": "ccw_unrew_frechet.pickle",
    "cw_unrew_frechet": "cw_unrew_frechet.pickle",
    "ccw_rew_frechet": "ccw_rew_frechet.pickle",
    "cw_rew_frechet": "cw_rew_frechet.pickle",
    "ccw_frechet": "ccw_frechet.pickle",
    "cw_frechet": "cw_frechet.pickle",
    "unrewarded_frechet": "unrewarded_frechet.pickle",
    "rewarded_frechet": "rewarded_frechet.pickle",
}

# %%
rewarded_turns_frechet_distances_per_session = {mouse: [] for mouse in mice_to_analyse}
unrewarded_turns_frechet_distances_per_session = {mouse: [] for mouse in mice_to_analyse}
cw_turns_frechet_distances_per_session = {mouse: [] for mouse in mice_to_analyse}
ccw_turns_frechet_distances_per_session = {mouse: [] for mouse in mice_to_analyse}
cw_rewarded_frechet_distances_per_session = {mouse: [] for mouse in mice_to_analyse}
ccw_rewarded_frechet_distances_per_session = {mouse: [] for mouse in mice_to_analyse}
cw_unrewarded_frechet_distances_per_session = {mouse: [] for mouse in mice_to_analyse}
ccw_unrewarded_frechet_distances_per_session = {mouse: [] for mouse in mice_to_analyse}

allsessionnumber = list(range(first_and_last_session_indexes[0] + 1,
                              first_and_last_session_indexes[1] + 1))

minimum_number_of_qts = 5

for mouse in mice_to_analyse:

    print(f"Computing/loading Fréchet distances for {mouse}")

    folder_path_mouse_to_process = os.path.join(path_to_data_folder, mouse)

    sessions_to_process = sorted([
        name for name in os.listdir(folder_path_mouse_to_process)
        if os.path.isdir(os.path.join(folder_path_mouse_to_process, name))
        and name.startswith("MOU")
    ])

    sessions_to_process = sessions_to_process[first_and_last_session_indexes[0]:first_and_last_session_indexes[1]]

    for session_index, session_to_process in enumerate(sessions_to_process):

        pickle_jar_path = get_pickle_jar_path(folder_path_mouse_to_process, session_to_process)

        if frechet_pickles_exist(pickle_jar_path, FRECHET_PICKLE_NAMES):
            frechet_results = load_frechet_pickles(pickle_jar_path, FRECHET_PICKLE_NAMES)
            print(f"  Session {session_to_process}: pickles already exist, loading.")
        else:
            print(f"  Session {session_to_process}: pickles do not exist, processing.")
            frechet_results = compute_frechet_for_one_session(
                folder_path_mouse_to_process,
                session_to_process,
                minimum_number_of_qts=minimum_number_of_qts
            )
            save_frechet_pickles(pickle_jar_path, frechet_results, FRECHET_PICKLE_NAMES)
            # print(f"Session {session_to_process}: processed and saved.")

        session_number = allsessionnumber[session_index]

        rewarded_turns_frechet_distances_per_session[mouse].append([session_number, frechet_results["rewarded_frechet"]])
        unrewarded_turns_frechet_distances_per_session[mouse].append([session_number, frechet_results["unrewarded_frechet"]])
        cw_turns_frechet_distances_per_session[mouse].append([session_number, frechet_results["cw_frechet"]])
        ccw_turns_frechet_distances_per_session[mouse].append([session_number, frechet_results["ccw_frechet"]])
        cw_rewarded_frechet_distances_per_session[mouse].append([session_number, frechet_results["cw_rew_frechet"]])
        ccw_rewarded_frechet_distances_per_session[mouse].append([session_number, frechet_results["ccw_rew_frechet"]])
        cw_unrewarded_frechet_distances_per_session[mouse].append([session_number, frechet_results["cw_unrew_frechet"]])
        ccw_unrewarded_frechet_distances_per_session[mouse].append([session_number, frechet_results["ccw_unrew_frechet"]])

    print(f"All {mouse} sessions processed and saved.")
# Out:
# Computing/loading Fréchet distances for MOUB6JRj748
#   Session MOUB6JRj748_20260109-1255: pickles already exist, loading.
#   Session MOUB6JRj748_20260109-1656: pickles already exist, loading.
#   Session MOUB6JRj748_20260113-1121: pickles already exist, loading.
#   Session MOUB6JRj748_20260113-1605: pickles already exist, loading.
#   Session MOUB6JRj748_20260114-1111: pickles already exist, loading.
#   Session MOUB6JRj748_20260114-1455: pickles already exist, loading.
#   Session MOUB6JRj748_20260115-1105: pickles already exist, loading.
#   Session MOUB6JRj748_20260115-1602: pickles already exist, loading.
#   Session MOUB6JRj748_20260116-1115: pickles already exist, loading.
#   Session MOUB6JRj748_20260116-1603: pickles already exist, loading.
#   Session MOUB6JRj748_20260117-1105: pickles already exist, loading.
#   Session MOUB6JRj748_20260117-1543: pickles already exist, loading.
#   Session MOUB6JRj748_20260118-1107: pickles already exist, loading.
#   Session MOUB6JRj748_20260118-1540: pickles already exist, loading.
#   Session MOUB6JRj748_20260119-1047: pickles already exist, loading.
#   Session MOUB6JRj748_20260119-1532: pickles already exist, loading.
#   Session MOUB6JRj748_20260120-1103: pickles already exist, loading.
#   Session MOUB6JRj748_20260120-1548: pickles already exist, loading.
#   Session MOUB6JRj748_20260121-1033: pickles already exist, loading.
#   Session MOUB6JRj748_20260121-1537: pickles already exist, loading.
#   Session MOUB6JRj748_20260122-1048: pickles already exist, loading.
#   Session MOUB6JRj748_20260122-1551: pickles already exist, loading.
#   Session MOUB6JRj748_20260123-1112: pickles already exist, loading.
#   Session MOUB6JRj748_20260123-1621: pickles already exist, loading.
#   Session MOUB6JRj748_20260124-1108: pickles already exist, loading.
#   Session MOUB6JRj748_20260124-1603: pickles already exist, loading.
#   Session MOUB6JRj748_20260125-1042: pickles already exist, loading.
#   Session MOUB6JRj748_20260125-1550: pickles already exist, loading.
#   Session MOUB6JRj748_20260126-1029: pickles already exist, loading.
#   Session MOUB6JRj748_20260126-1526: pickles already exist, loading.
#   Session MOUB6JRj748_20260127-1046: pickles already exist, loading.
#   Session MOUB6JRj748_20260127-1559: pickles already exist, loading.
# All MOUB6JRj748 sessions processed and saved.
# Computing/loading Fréchet distances for MOUB6JRj749
#   Session MOUB6JRj749_20260109-1312: pickles already exist, loading.
#   Session MOUB6JRj749_20260109-1713: pickles already exist, loading.
#   Session MOUB6JRj749_20260113-1138: pickles already exist, loading.
#   Session MOUB6JRj749_20260113-1622: pickles already exist, loading.
#   Session MOUB6JRj749_20260114-1127: pickles already exist, loading.
#   Session MOUB6JRj749_20260114-1626: pickles already exist, loading.
#   Session MOUB6JRj749_20260115-1118: pickles already exist, loading.
#   Session MOUB6JRj749_20260115-1624: pickles already exist, loading.
#   Session MOUB6JRj749_20260116-1130: pickles already exist, loading.
#   Session MOUB6JRj749_20260116-1618: pickles already exist, loading.
#   Session MOUB6JRj749_20260117-1119: pickles already exist, loading.
#   Session MOUB6JRj749_20260117-1558: pickles already exist, loading.
#   Session MOUB6JRj749_20260118-1121: pickles already exist, loading.
#   Session MOUB6JRj749_20260118-1554: pickles already exist, loading.
#   Session MOUB6JRj749_20260119-1101: pickles already exist, loading.
#   Session MOUB6JRj749_20260119-1548: pickles already exist, loading.
#   Session MOUB6JRj749_20260120-1118: pickles already exist, loading.
#   Session MOUB6JRj749_20260120-1603: pickles already exist, loading.
#   Session MOUB6JRj749_20260121-1047: pickles already exist, loading.
#   Session MOUB6JRj749_20260121-1550: pickles already exist, loading.
#   Session MOUB6JRj749_20260122-1102: pickles already exist, loading.
#   Session MOUB6JRj749_20260122-1606: pickles already exist, loading.
#   Session MOUB6JRj749_20260123-1127: pickles already exist, loading.
#   Session MOUB6JRj749_20260123-1638: pickles already exist, loading.
#   Session MOUB6JRj749_20260124-1122: pickles already exist, loading.
#   Session MOUB6JRj749_20260124-1617: pickles already exist, loading.
#   Session MOUB6JRj749_20260125-1056: pickles already exist, loading.
#   Session MOUB6JRj749_20260125-1604: pickles already exist, loading.
#   Session MOUB6JRj749_20260126-1045: pickles already exist, loading.
#   Session MOUB6JRj749_20260126-1540: pickles already exist, loading.
#   Session MOUB6JRj749_20260127-1107: pickles already exist, loading.
#   Session MOUB6JRj749_20260127-1618: pickles already exist, loading.
# All MOUB6JRj749 sessions processed and saved.
# Computing/loading Fréchet distances for MOUB6JRj750
#   Session MOUB6JRj750_20260109-1330: pickles already exist, loading.
#   Session MOUB6JRj750_20260109-1729: pickles already exist, loading.
#   Session MOUB6JRj750_20260113-1155: pickles already exist, loading.
#   Session MOUB6JRj750_20260113-1644: pickles already exist, loading.
#   Session MOUB6JRj750_20260114-1141: pickles already exist, loading.
#   Session MOUB6JRj750_20260114-1642: pickles already exist, loading.
#   Session MOUB6JRj750_20260115-1133: pickles already exist, loading.
#   Session MOUB6JRj750_20260115-1638: pickles already exist, loading.
#   Session MOUB6JRj750_20260116-1144: pickles already exist, loading.
#   Session MOUB6JRj750_20260116-1632: pickles already exist, loading.
#   Session MOUB6JRj750_20260117-1133: pickles already exist, loading.
#   Session MOUB6JRj750_20260117-1613: pickles already exist, loading.
#   Session MOUB6JRj750_20260118-1134: pickles already exist, loading.
#   Session MOUB6JRj750_20260118-1608: pickles already exist, loading.
#   Session MOUB6JRj750_20260119-1114: pickles already exist, loading.
#   Session MOUB6JRj750_20260119-1603: pickles already exist, loading.
#   Session MOUB6JRj750_20260120-1132: pickles already exist, loading.
#   Session MOUB6JRj750_20260120-1616: pickles already exist, loading.
#   Session MOUB6JRj750_20260121-1101: pickles already exist, loading.
#   Session MOUB6JRj750_20260121-1604: pickles already exist, loading.
#   Session MOUB6JRj750_20260122-1120: pickles already exist, loading.
#   Session MOUB6JRj750_20260122-1619: pickles already exist, loading.
#   Session MOUB6JRj750_20260123-1143: pickles already exist, loading.
#   Session MOUB6JRj750_20260123-1653: pickles already exist, loading.
#   Session MOUB6JRj750_20260124-1136: pickles already exist, loading.
#   Session MOUB6JRj750_20260124-1631: pickles already exist, loading.
#   Session MOUB6JRj750_20260125-1112: pickles already exist, loading.
#   Session MOUB6JRj750_20260125-1619: pickles already exist, loading.
#   Session MOUB6JRj750_20260126-1059: pickles already exist, loading.
#   Session MOUB6JRj750_20260126-1553: pickles already exist, loading.
#   Session MOUB6JRj750_20260127-1124: pickles already exist, loading.
#   Session MOUB6JRj750_20260127-1633: pickles already exist, loading.
# All MOUB6JRj750 sessions processed and saved.
# Computing/loading Fréchet distances for MOUB6JRj751
#   Session MOUB6JRj751_20260109-1350: pickles already exist, loading.
#   Session MOUB6JRj751_20260109-1750: pickles already exist, loading.
#   Session MOUB6JRj751_20260113-1215: pickles already exist, loading.
#   Session MOUB6JRj751_20260113-1701: pickles already exist, loading.
#   Session MOUB6JRj751_20260114-1157: pickles already exist, loading.
#   Session MOUB6JRj751_20260114-1656: pickles already exist, loading.
#   Session MOUB6JRj751_20260115-1148: pickles already exist, loading.
#   Session MOUB6JRj751_20260115-1652: pickles already exist, loading.
#   Session MOUB6JRj751_20260116-1159: pickles already exist, loading.
#   Session MOUB6JRj751_20260116-1647: pickles already exist, loading.
#   Session MOUB6JRj751_20260117-1149: pickles already exist, loading.
#   Session MOUB6JRj751_20260117-1629: pickles already exist, loading.
#   Session MOUB6JRj751_20260118-1149: pickles already exist, loading.
#   Session MOUB6JRj751_20260118-1623: pickles already exist, loading.
#   Session MOUB6JRj751_20260119-1128: pickles already exist, loading.
#   Session MOUB6JRj751_20260119-1618: pickles already exist, loading.
#   Session MOUB6JRj751_20260120-1147: pickles already exist, loading.
#   Session MOUB6JRj751_20260120-1631: pickles already exist, loading.
#   Session MOUB6JRj751_20260121-1116: pickles already exist, loading.
#   Session MOUB6JRj751_20260121-1620: pickles already exist, loading.
#   Session MOUB6JRj751_20260122-1138: pickles already exist, loading.
#   Session MOUB6JRj751_20260122-1635: pickles already exist, loading.
#   Session MOUB6JRj751_20260123-1159: pickles already exist, loading.
#   Session MOUB6JRj751_20260123-1709: pickles already exist, loading.
#   Session MOUB6JRj751_20260124-1150: pickles already exist, loading.
#   Session MOUB6JRj751_20260124-1647: pickles already exist, loading.
#   Session MOUB6JRj751_20260125-1127: pickles already exist, loading.
#   Session MOUB6JRj751_20260125-1634: pickles already exist, loading.
#   Session MOUB6JRj751_20260126-1114: pickles already exist, loading.
#   Session MOUB6JRj751_20260126-1610: pickles already exist, loading.
#   Session MOUB6JRj751_20260127-1140: pickles already exist, loading.
#   Session MOUB6JRj751_20260127-1647: pickles already exist, loading.
# All MOUB6JRj751 sessions processed and saved.
# Computing/loading Fréchet distances for MOUB6JRj752
#   Session MOUB6JRj752_20260109-1409: pickles already exist, loading.
#   Session MOUB6JRj752_20260109-1807: pickles already exist, loading.
#   Session MOUB6JRj752_20260113-1231: pickles already exist, loading.
#   Session MOUB6JRj752_20260113-1719: pickles already exist, loading.
#   Session MOUB6JRj752_20260114-1216: pickles already exist, loading.
#   Session MOUB6JRj752_20260114-1710: pickles already exist, loading.
#   Session MOUB6JRj752_20260115-1211: pickles already exist, loading.
#   Session MOUB6JRj752_20260115-1710: pickles already exist, loading.
#   Session MOUB6JRj752_20260116-1214: pickles already exist, loading.
#   Session MOUB6JRj752_20260116-1703: pickles already exist, loading.
#   Session MOUB6JRj752_20260117-1205: pickles already exist, loading.
#   Session MOUB6JRj752_20260117-1644: pickles already exist, loading.
#   Session MOUB6JRj752_20260118-1203: pickles already exist, loading.
#   Session MOUB6JRj752_20260118-1637: pickles already exist, loading.
#   Session MOUB6JRj752_20260119-1142: pickles already exist, loading.
#   Session MOUB6JRj752_20260119-1632: pickles already exist, loading.
#   Session MOUB6JRj752_20260120-1204: pickles already exist, loading.
#   Session MOUB6JRj752_20260120-1645: pickles already exist, loading.
#   Session MOUB6JRj752_20260121-1133: pickles already exist, loading.
#   Session MOUB6JRj752_20260121-1635: pickles already exist, loading.
#   Session MOUB6JRj752_20260122-1153: pickles already exist, loading.
#   Session MOUB6JRj752_20260122-1650: pickles already exist, loading.
#   Session MOUB6JRj752_20260123-1216: pickles already exist, loading.
#   Session MOUB6JRj752_20260123-1722: pickles already exist, loading.
#   Session MOUB6JRj752_20260124-1206: pickles already exist, loading.
#   Session MOUB6JRj752_20260124-1702: pickles already exist, loading.
#   Session MOUB6JRj752_20260125-1147: pickles already exist, loading.
#   Session MOUB6JRj752_20260125-1650: pickles already exist, loading.
#   Session MOUB6JRj752_20260126-1130: pickles already exist, loading.
#   Session MOUB6JRj752_20260126-1624: pickles already exist, loading.
#   Session MOUB6JRj752_20260127-1156: pickles already exist, loading.
#   Session MOUB6JRj752_20260127-1702: pickles already exist, loading.
# All MOUB6JRj752 sessions processed and saved.
# Computing/loading Fréchet distances for MOU5465
#   Session MOU5465_20260323-1138: pickles already exist, loading.
#   Session MOU5465_20260323-1603: pickles already exist, loading.
#   Session MOU5465_20260324-1210: pickles already exist, loading.
#   Session MOU5465_20260324-1637: pickles already exist, loading.
#   Session MOU5465_20260325-1133: pickles already exist, loading.
#   Session MOU5465_20260325-1621: pickles already exist, loading.
#   Session MOU5465_20260326-1112: pickles already exist, loading.
#   Session MOU5465_20260326-1621: pickles already exist, loading.
#   Session MOU5465_20260327-1105: pickles already exist, loading.
#   Session MOU5465_20260327-1608: pickles already exist, loading.
#   Session MOU5465_20260328-1059: pickles already exist, loading.
#   Session MOU5465_20260328-1549: pickles already exist, loading.
#   Session MOU5465_20260329-1124: pickles already exist, loading.
#   Session MOU5465_20260329-1603: pickles already exist, loading.
#   Session MOU5465_20260330-1119: pickles already exist, loading.
#   Session MOU5465_20260330-1608: pickles already exist, loading.
#   Session MOU5465_20260331-1116: pickles already exist, loading.
#   Session MOU5465_20260331-1612: pickles already exist, loading.
#   Session MOU5465_20260401-1113: pickles already exist, loading.
#   Session MOU5465_20260401-1613: pickles already exist, loading.
#   Session MOU5465_20260402-1220: pickles already exist, loading.
#   Session MOU5465_20260402-1713: pickles already exist, loading.
#   Session MOU5465_20260403-1207: pickles already exist, loading.
#   Session MOU5465_20260403-1633: pickles already exist, loading.
#   Session MOU5465_20260404-1113: pickles already exist, loading.
#   Session MOU5465_20260404-1610: pickles already exist, loading.
#   Session MOU5465_20260405-1149: pickles already exist, loading.
#   Session MOU5465_20260405-1645: pickles already exist, loading.
#   Session MOU5465_20260406-1113: pickles already exist, loading.
#   Session MOU5465_20260406-1616: pickles already exist, loading.
#   Session MOU5465_20260407-1143: pickles already exist, loading.
# All MOU5465 sessions processed and saved.
# Computing/loading Fréchet distances for MOU5468
#   Session MOU5468_20260323-1156: pickles already exist, loading.
#   Session MOU5468_20260323-1620: pickles already exist, loading.
#   Session MOU5468_20260324-1227: pickles already exist, loading.
#   Session MOU5468_20260324-1654: pickles already exist, loading.
#   Session MOU5468_20260325-1150: pickles already exist, loading.
#   Session MOU5468_20260325-1636: pickles already exist, loading.
#   Session MOU5468_20260326-1127: pickles already exist, loading.
#   Session MOU5468_20260326-1635: pickles already exist, loading.
#   Session MOU5468_20260327-1119: pickles already exist, loading.
#   Session MOU5468_20260327-1622: pickles already exist, loading.
#   Session MOU5468_20260328-1113: pickles already exist, loading.
#   Session MOU5468_20260328-1603: pickles already exist, loading.
#   Session MOU5468_20260329-1139: pickles already exist, loading.
#   Session MOU5468_20260329-1617: pickles already exist, loading.
#   Session MOU5468_20260330-1132: pickles already exist, loading.
#   Session MOU5468_20260330-1622: pickles already exist, loading.
#   Session MOU5468_20260331-1131: pickles already exist, loading.
#   Session MOU5468_20260331-1626: pickles already exist, loading.
#   Session MOU5468_20260401-1128: pickles already exist, loading.
#   Session MOU5468_20260401-1627: pickles already exist, loading.
#   Session MOU5468_20260402-1234: pickles already exist, loading.
#   Session MOU5468_20260402-1726: pickles already exist, loading.
#   Session MOU5468_20260403-1221: pickles already exist, loading.
#   Session MOU5468_20260403-1647: pickles already exist, loading.
#   Session MOU5468_20260404-1128: pickles already exist, loading.
#   Session MOU5468_20260404-1625: pickles already exist, loading.
#   Session MOU5468_20260405-1204: pickles already exist, loading.
#   Session MOU5468_20260405-1701: pickles already exist, loading.
#   Session MOU5468_20260406-1131: pickles already exist, loading.
#   Session MOU5468_20260406-1633: pickles already exist, loading.
#   Session MOU5468_20260407-1159: pickles already exist, loading.
# All MOU5468 sessions processed and saved.
# Computing/loading Fréchet distances for MOU5500
#   Session MOU5500_20260420-1117: pickles already exist, loading.
#   Session MOU5500_20260420-1621: pickles already exist, loading.
#   Session MOU5500_20260421-1106: pickles already exist, loading.
#   Session MOU5500_20260421-1641: pickles already exist, loading.
#   Session MOU5500_20260422-1055: pickles already exist, loading.
#   Session MOU5500_20260422-1559: pickles already exist, loading.
#   Session MOU5500_20260423-1100: pickles already exist, loading.
#   Session MOU5500_20260423-1607: pickles already exist, loading.
#   Session MOU5500_20260424-1053: pickles already exist, loading.
#   Session MOU5500_20260424-1602: pickles already exist, loading.
#   Session MOU5500_20260425-1100: pickles already exist, loading.
#   Session MOU5500_20260425-1540: pickles already exist, loading.
#   Session MOU5500_20260426-1121: pickles already exist, loading.
#   Session MOU5500_20260426-1644: pickles already exist, loading.
# All MOU5500 sessions processed and saved.
# Computing/loading Fréchet distances for MOU5501
#   Session MOU5501_20260420-1134: pickles already exist, loading.
#   Session MOU5501_20260420-1638: pickles already exist, loading.
#   Session MOU5501_20260421-1127: pickles already exist, loading.
#   Session MOU5501_20260421-1700: pickles already exist, loading.
#   Session MOU5501_20260422-1110: pickles already exist, loading.
#   Session MOU5501_20260422-1615: pickles already exist, loading.
#   Session MOU5501_20260423-1116: pickles already exist, loading.
#   Session MOU5501_20260423-1627: pickles already exist, loading.
#   Session MOU5501_20260424-1108: pickles already exist, loading.
#   Session MOU5501_20260424-1617: pickles already exist, loading.
#   Session MOU5501_20260425-1115: pickles do not exist, processing.
#   Session MOU5501_20260425-1554: pickles do not exist, processing.
#   Session MOU5501_20260426-1135: pickles already exist, loading.
#   Session MOU5501_20260426-1659: pickles do not exist, processing.
# All MOU5501 sessions processed and saved.
# Computing/loading Fréchet distances for MOUB6JRj753
#   Session MOUB6JRj753_20260109-1001: pickles already exist, loading.
#   Session MOUB6JRj753_20260109-1528: pickles already exist, loading.
#   Session MOUB6JRj753_20260113-0952: pickles already exist, loading.
#   Session MOUB6JRj753_20260113-1431: pickles already exist, loading.
#   Session MOUB6JRj753_20260114-1001: pickles already exist, loading.
#   Session MOUB6JRj753_20260114-1510: pickles already exist, loading.
#   Session MOUB6JRj753_20260115-0953: pickles already exist, loading.
#   Session MOUB6JRj753_20260115-1448: pickles already exist, loading.
#   Session MOUB6JRj753_20260116-0948: pickles already exist, loading.
#   Session MOUB6JRj753_20260116-1449: pickles already exist, loading.
#   Session MOUB6JRj753_20260117-1008: pickles already exist, loading.
#   Session MOUB6JRj753_20260117-1500: pickles already exist, loading.
#   Session MOUB6JRj753_20260118-1012: pickles already exist, loading.
#   Session MOUB6JRj753_20260118-1440: pickles already exist, loading.
#   Session MOUB6JRj753_20260119-1002: pickles already exist, loading.
#   Session MOUB6JRj753_20260119-1447: pickles already exist, loading.
#   Session MOUB6JRj753_20260120-1015: pickles already exist, loading.
#   Session MOUB6JRj753_20260120-1505: pickles already exist, loading.
#   Session MOUB6JRj753_20260121-0949: pickles already exist, loading.
#   Session MOUB6JRj753_20260121-1447: pickles already exist, loading.
#   Session MOUB6JRj753_20260122-1001: pickles already exist, loading.
#   Session MOUB6JRj753_20260122-1506: pickles already exist, loading.
#   Session MOUB6JRj753_20260123-1024: pickles already exist, loading.
#   Session MOUB6JRj753_20260123-1534: pickles already exist, loading.
#   Session MOUB6JRj753_20260124-1024: pickles already exist, loading.
#   Session MOUB6JRj753_20260124-1520: pickles already exist, loading.
#   Session MOUB6JRj753_20260125-0959: pickles already exist, loading.
#   Session MOUB6JRj753_20260125-1503: pickles already exist, loading.
#   Session MOUB6JRj753_20260126-0942: pickles already exist, loading.
#   Session MOUB6JRj753_20260126-1445: pickles already exist, loading.
#   Session MOUB6JRj753_20260127-1001: pickles already exist, loading.
#   Session MOUB6JRj753_20260127-1508: pickles already exist, loading.
# All MOUB6JRj753 sessions processed and saved.
# Computing/loading Fréchet distances for MOUB6JRj755
#   Session MOUB6JRj755_20260109-1203: pickles already exist, loading.
#   Session MOUB6JRj755_20260109-1602: pickles already exist, loading.
#   Session MOUB6JRj755_20260113-1027: pickles already exist, loading.
#   Session MOUB6JRj755_20260113-1507: pickles already exist, loading.
#   Session MOUB6JRj755_20260114-1028: pickles already exist, loading.
#   Session MOUB6JRj755_20260114-1538: pickles already exist, loading.
#   Session MOUB6JRj755_20260115-1020: pickles already exist, loading.
#   Session MOUB6JRj755_20260115-1519: pickles already exist, loading.
#   Session MOUB6JRj755_20260116-1018: pickles already exist, loading.
#   Session MOUB6JRj755_20260116-1518: pickles already exist, loading.
#   Session MOUB6JRj755_20260117-1022: pickles already exist, loading.
#   Session MOUB6JRj755_20260117-1445: pickles already exist, loading.
#   Session MOUB6JRj755_20260118-1025: pickles already exist, loading.
#   Session MOUB6JRj755_20260118-1454: pickles already exist, loading.
#   Session MOUB6JRj755_20260119-1016: pickles already exist, loading.
#   Session MOUB6JRj755_20260119-1503: pickles already exist, loading.
#   Session MOUB6JRj755_20260120-1029: pickles already exist, loading.
#   Session MOUB6JRj755_20260120-1520: pickles already exist, loading.
#   Session MOUB6JRj755_20260121-1003: pickles already exist, loading.
#   Session MOUB6JRj755_20260121-1505: pickles already exist, loading.
#   Session MOUB6JRj755_20260122-1017: pickles already exist, loading.
#   Session MOUB6JRj755_20260122-1521: pickles already exist, loading.
#   Session MOUB6JRj755_20260123-1038: pickles already exist, loading.
#   Session MOUB6JRj755_20260123-1549: pickles already exist, loading.
#   Session MOUB6JRj755_20260124-1039: pickles already exist, loading.
#   Session MOUB6JRj755_20260124-1534: pickles already exist, loading.
#   Session MOUB6JRj755_20260125-1013: pickles already exist, loading.
#   Session MOUB6JRj755_20260125-1518: pickles already exist, loading.
#   Session MOUB6JRj755_20260126-0957: pickles already exist, loading.
#   Session MOUB6JRj755_20260126-1459: pickles already exist, loading.
#   Session MOUB6JRj755_20260127-1015: pickles already exist, loading.
#   Session MOUB6JRj755_20260127-1523: pickles already exist, loading.
# All MOUB6JRj755 sessions processed and saved.
# Computing/loading Fréchet distances for MOUB6JRj756
#   Session MOUB6JRj756_20260109-1221: pickles already exist, loading.
#   Session MOUB6JRj756_20260109-1619: pickles already exist, loading.
#   Session MOUB6JRj756_20260113-1045: pickles already exist, loading.
#   Session MOUB6JRj756_20260113-1526: pickles already exist, loading.
#   Session MOUB6JRj756_20260114-1043: pickles already exist, loading.
#   Session MOUB6JRj756_20260114-1554: pickles already exist, loading.
#   Session MOUB6JRj756_20260115-1035: pickles already exist, loading.
#   Session MOUB6JRj756_20260115-1535: pickles already exist, loading.
#   Session MOUB6JRj756_20260116-1034: pickles already exist, loading.
#   Session MOUB6JRj756_20260116-1533: pickles already exist, loading.
#   Session MOUB6JRj756_20260117-1036: pickles already exist, loading.
#   Session MOUB6JRj756_20260117-1516: pickles already exist, loading.
#   Session MOUB6JRj756_20260118-1040: pickles already exist, loading.
#   Session MOUB6JRj756_20260118-1510: pickles already exist, loading.
#   Session MOUB6JRj756_20260119-1033: pickles already exist, loading.
#   Session MOUB6JRj756_20260119-1518: pickles already exist, loading.
#   Session MOUB6JRj756_20260120-1047: pickles already exist, loading.
#   Session MOUB6JRj756_20260120-1534: pickles already exist, loading.
#   Session MOUB6JRj756_20260121-1018: pickles already exist, loading.
#   Session MOUB6JRj756_20260121-1522: pickles already exist, loading.
#   Session MOUB6JRj756_20260122-1033: pickles already exist, loading.
#   Session MOUB6JRj756_20260122-1537: pickles already exist, loading.
#   Session MOUB6JRj756_20260123-1053: pickles already exist, loading.
#   Session MOUB6JRj756_20260123-1605: pickles already exist, loading.
#   Session MOUB6JRj756_20260124-1053: pickles already exist, loading.
#   Session MOUB6JRj756_20260124-1549: pickles already exist, loading.
#   Session MOUB6JRj756_20260125-1028: pickles already exist, loading.
#   Session MOUB6JRj756_20260125-1533: pickles already exist, loading.
#   Session MOUB6JRj756_20260126-1013: pickles already exist, loading.
#   Session MOUB6JRj756_20260126-1512: pickles already exist, loading.
#   Session MOUB6JRj756_20260127-1031: pickles already exist, loading.
#   Session MOUB6JRj756_20260127-1539: pickles already exist, loading.
# All MOUB6JRj756 sessions processed and saved.
# Computing/loading Fréchet distances for MOU5289
#   Session MOU5289_20260223-1132: pickles already exist, loading.
#   Session MOU5289_20260223-1622: pickles already exist, loading.
#   Session MOU5289_20260224-1225: pickles already exist, loading.
#   Session MOU5289_20260224-1655: pickles already exist, loading.
#   Session MOU5289_20260225-1154: pickles already exist, loading.
#   Session MOU5289_20260225-1659: pickles already exist, loading.
#   Session MOU5289_20260226-1145: pickles already exist, loading.
#   Session MOU5289_20260226-1647: pickles already exist, loading.
#   Session MOU5289_20260227-1124: pickles already exist, loading.
#   Session MOU5289_20260227-1603: pickles already exist, loading.
#   Session MOU5289_20260228-1031: pickles already exist, loading.
#   Session MOU5289_20260228-1535: pickles already exist, loading.
#   Session MOU5289_20260301-1012: pickles already exist, loading.
#   Session MOU5289_20260301-1514: pickles already exist, loading.
#   Session MOU5289_20260302-1028: pickles already exist, loading.
#   Session MOU5289_20260302-1536: pickles already exist, loading.
#   Session MOU5289_20260303-1035: pickles already exist, loading.
#   Session MOU5289_20260303-1538: pickles already exist, loading.
#   Session MOU5289_20260304-1043: pickles already exist, loading.
#   Session MOU5289_20260304-1544: pickles already exist, loading.
#   Session MOU5289_20260305-1056: pickles already exist, loading.
#   Session MOU5289_20260305-1607: pickles already exist, loading.
#   Session MOU5289_20260306-0952: pickles already exist, loading.
#   Session MOU5289_20260306-1554: pickles already exist, loading.
#   Session MOU5289_20260307-1020: pickles already exist, loading.
#   Session MOU5289_20260307-1522: pickles already exist, loading.
#   Session MOU5289_20260308-1015: pickles already exist, loading.
#   Session MOU5289_20260308-1527: pickles already exist, loading.
#   Session MOU5289_20260309-1022: pickles already exist, loading.
#   Session MOU5289_20260309-1529: pickles already exist, loading.
#   Session MOU5289_20260310-1047: pickles already exist, loading.
#   Session MOU5289_20260310-1543: pickles already exist, loading.
# All MOU5289 sessions processed and saved.
# Computing/loading Fréchet distances for MOU5291
#   Session MOU5291_20260223-1150: pickles already exist, loading.
#   Session MOU5291_20260223-1640: pickles already exist, loading.
#   Session MOU5291_20260224-1248: pickles already exist, loading.
#   Session MOU5291_20260224-1711: pickles already exist, loading.
#   Session MOU5291_20260225-1220: pickles already exist, loading.
#   Session MOU5291_20260225-1716: pickles already exist, loading.
#   Session MOU5291_20260226-1206: pickles already exist, loading.
#   Session MOU5291_20260226-1703: pickles already exist, loading.
#   Session MOU5291_20260227-1144: pickles already exist, loading.
#   Session MOU5291_20260227-1620: pickles already exist, loading.
#   Session MOU5291_20260228-1045: pickles already exist, loading.
#   Session MOU5291_20260228-1549: pickles already exist, loading.
#   Session MOU5291_20260301-1027: pickles already exist, loading.
#   Session MOU5291_20260301-1528: pickles already exist, loading.
#   Session MOU5291_20260302-1045: pickles already exist, loading.
#   Session MOU5291_20260302-1554: pickles already exist, loading.
#   Session MOU5291_20260303-1049: pickles already exist, loading.
#   Session MOU5291_20260303-1552: pickles already exist, loading.
#   Session MOU5291_20260304-1058: pickles already exist, loading.
#   Session MOU5291_20260304-1559: pickles already exist, loading.
#   Session MOU5291_20260305-1111: pickles already exist, loading.
#   Session MOU5291_20260305-1622: pickles already exist, loading.
#   Session MOU5291_20260306-1005: pickles already exist, loading.
#   Session MOU5291_20260306-1511: pickles already exist, loading.
#   Session MOU5291_20260307-1034: pickles already exist, loading.
#   Session MOU5291_20260307-1536: pickles already exist, loading.
#   Session MOU5291_20260308-1030: pickles already exist, loading.
#   Session MOU5291_20260308-1542: pickles already exist, loading.
#   Session MOU5291_20260309-1037: pickles already exist, loading.
#   Session MOU5291_20260309-1543: pickles already exist, loading.
#   Session MOU5291_20260310-1102: pickles already exist, loading.
#   Session MOU5291_20260310-1558: pickles already exist, loading.
# All MOU5291 sessions processed and saved.
# Computing/loading Fréchet distances for MOU5413
#   Session MOU5413_20260223-1230: pickles already exist, loading.
#   Session MOU5413_20260223-1715: pickles already exist, loading.
#   Session MOU5413_20260224-1323: pickles already exist, loading.
#   Session MOU5413_20260224-1745: pickles already exist, loading.
#   Session MOU5413_20260225-1248: pickles already exist, loading.
#   Session MOU5413_20260225-1744: pickles already exist, loading.
#   Session MOU5413_20260226-1239: pickles already exist, loading.
#   Session MOU5413_20260226-1718: pickles already exist, loading.
#   Session MOU5413_20260227-1200: pickles already exist, loading.
#   Session MOU5413_20260227-1634: pickles already exist, loading.
#   Session MOU5413_20260228-1100: pickles already exist, loading.
#   Session MOU5413_20260228-1604: pickles already exist, loading.
#   Session MOU5413_20260301-1042: pickles already exist, loading.
#   Session MOU5413_20260301-1542: pickles already exist, loading.
#   Session MOU5413_20260302-1104: pickles already exist, loading.
#   Session MOU5413_20260302-1609: pickles already exist, loading.
#   Session MOU5413_20260303-1105: pickles already exist, loading.
#   Session MOU5413_20260303-1606: pickles already exist, loading.
#   Session MOU5413_20260304-1114: pickles already exist, loading.
#   Session MOU5413_20260304-1614: pickles already exist, loading.
#   Session MOU5413_20260305-1128: pickles already exist, loading.
#   Session MOU5413_20260305-1638: pickles already exist, loading.
#   Session MOU5413_20260306-1019: pickles already exist, loading.
#   Session MOU5413_20260306-1525: pickles already exist, loading.
#   Session MOU5413_20260307-1049: pickles already exist, loading.
#   Session MOU5413_20260307-1551: pickles already exist, loading.
#   Session MOU5413_20260308-1045: pickles already exist, loading.
#   Session MOU5413_20260308-1600: pickles already exist, loading.
#   Session MOU5413_20260309-1053: pickles already exist, loading.
#   Session MOU5413_20260309-1558: pickles already exist, loading.
#   Session MOU5413_20260310-1118: pickles already exist, loading.
#   Session MOU5413_20260310-1616: pickles already exist, loading.
# All MOU5413 sessions processed and saved.
# Computing/loading Fréchet distances for MOU5415
#   Session MOU5415_20260223-1249: pickles already exist, loading.
#   Session MOU5415_20260223-1734: pickles already exist, loading.
#   Session MOU5415_20260224-1343: pickles already exist, loading.
#   Session MOU5415_20260224-1801: pickles already exist, loading.
#   Session MOU5415_20260225-1302: pickles already exist, loading.
#   Session MOU5415_20260225-1758: pickles already exist, loading.
#   Session MOU5415_20260226-1253: pickles already exist, loading.
#   Session MOU5415_20260226-1734: pickles already exist, loading.
#   Session MOU5415_20260227-1215: pickles already exist, loading.
#   Session MOU5415_20260227-1650: pickles already exist, loading.
#   Session MOU5415_20260228-1119: pickles already exist, loading.
#   Session MOU5415_20260228-1620: pickles already exist, loading.
#   Session MOU5415_20260301-1056: pickles already exist, loading.
#   Session MOU5415_20260301-1556: pickles already exist, loading.
#   Session MOU5415_20260302-1119: pickles already exist, loading.
#   Session MOU5415_20260302-1625: pickles already exist, loading.
#   Session MOU5415_20260303-1118: pickles already exist, loading.
#   Session MOU5415_20260303-1621: pickles already exist, loading.
#   Session MOU5415_20260304-1131: pickles already exist, loading.
#   Session MOU5415_20260304-1629: pickles already exist, loading.
#   Session MOU5415_20260305-1144: pickles already exist, loading.
#   Session MOU5415_20260305-1651: pickles already exist, loading.
#   Session MOU5415_20260306-1034: pickles already exist, loading.
#   Session MOU5415_20260306-1539: pickles already exist, loading.
#   Session MOU5415_20260307-1104: pickles already exist, loading.
#   Session MOU5415_20260307-1605: pickles already exist, loading.
#   Session MOU5415_20260308-1059: pickles already exist, loading.
#   Session MOU5415_20260308-1616: pickles already exist, loading.
#   Session MOU5415_20260309-1111: pickles already exist, loading.
#   Session MOU5415_20260309-1612: pickles already exist, loading.
#   Session MOU5415_20260310-1134: pickles already exist, loading.
#   Session MOU5415_20260310-1630: pickles already exist, loading.
# All MOU5415 sessions processed and saved.
# Computing/loading Fréchet distances for MOU5471
#   Session MOU5471_20260323-0915: pickles already exist, loading.
#   Session MOU5471_20260323-1341: pickles already exist, loading.
#   Session MOU5471_20260324-0950: pickles already exist, loading.
#   Session MOU5471_20260324-1416: pickles already exist, loading.
#   Session MOU5471_20260325-0918: pickles already exist, loading.
#   Session MOU5471_20260325-1419: pickles already exist, loading.
#   Session MOU5471_20260326-0911: pickles already exist, loading.
#   Session MOU5471_20260326-1418: pickles already exist, loading.
#   Session MOU5471_20260327-0908: pickles already exist, loading.
#   Session MOU5471_20260327-1413: pickles already exist, loading.
#   Session MOU5471_20260328-0854: pickles already exist, loading.
#   Session MOU5471_20260328-1352: pickles already exist, loading.
#   Session MOU5471_20260329-0920: pickles already exist, loading.
#   Session MOU5471_20260329-1407: pickles already exist, loading.
#   Session MOU5471_20260330-0918: pickles already exist, loading.
#   Session MOU5471_20260330-1415: pickles already exist, loading.
#   Session MOU5471_20260331-0912: pickles already exist, loading.
#   Session MOU5471_20260331-1418: pickles already exist, loading.
#   Session MOU5471_20260401-0914: pickles already exist, loading.
#   Session MOU5471_20260401-1418: pickles already exist, loading.
#   Session MOU5471_20260402-1016: pickles already exist, loading.
#   Session MOU5471_20260402-1521: pickles already exist, loading.
#   Session MOU5471_20260403-1018: pickles already exist, loading.
#   Session MOU5471_20260403-1442: pickles already exist, loading.
#   Session MOU5471_20260404-0915: pickles already exist, loading.
#   Session MOU5471_20260404-1416: pickles already exist, loading.
#   Session MOU5471_20260405-0950: pickles already exist, loading.
#   Session MOU5471_20260405-1453: pickles already exist, loading.
#   Session MOU5471_20260406-0911: pickles already exist, loading.
#   Session MOU5471_20260406-1423: pickles already exist, loading.
#   Session MOU5471_20260407-0940: pickles already exist, loading.
# All MOU5471 sessions processed and saved.
# Computing/loading Fréchet distances for MOU5496
#   Session MOU5496_20260420-1016: pickles already exist, loading.
#   Session MOU5496_20260420-1522: pickles already exist, loading.
#   Session MOU5496_20260421-0959: pickles already exist, loading.
#   Session MOU5496_20260421-1536: pickles already exist, loading.
#   Session MOU5496_20260422-0958: pickles already exist, loading.
#   Session MOU5496_20260422-1505: pickles already exist, loading.
#   Session MOU5496_20260423-1008: pickles already exist, loading.
#   Session MOU5496_20260423-1509: pickles already exist, loading.
#   Session MOU5496_20260424-0957: pickles already exist, loading.
#   Session MOU5496_20260424-1502: pickles already exist, loading.
#   Session MOU5496_20260425-1017: pickles already exist, loading.
#   Session MOU5496_20260425-1453: pickles already exist, loading.
#   Session MOU5496_20260426-0959: pickles already exist, loading.
#   Session MOU5496_20260426-1535: pickles already exist, loading.
# All MOU5496 sessions processed and saved.
# Computing/loading Fréchet distances for MOU5498
#   Session MOU5498_20260420-1034: pickles already exist, loading.
#   Session MOU5498_20260420-1541: pickles already exist, loading.
#   Session MOU5498_20260421-1022: pickles already exist, loading.
#   Session MOU5498_20260421-1557: pickles already exist, loading.
#   Session MOU5498_20260422-1015: pickles already exist, loading.
#   Session MOU5498_20260422-1520: pickles already exist, loading.
#   Session MOU5498_20260423-1024: pickles already exist, loading.
#   Session MOU5498_20260423-1524: pickles already exist, loading.
#   Session MOU5498_20260424-1015: pickles already exist, loading.
#   Session MOU5498_20260424-1519: pickles already exist, loading.
#   Session MOU5498_20260425-1030: pickles already exist, loading.
#   Session MOU5498_20260425-1508: pickles already exist, loading.
#   Session MOU5498_20260426-1013: pickles already exist, loading.
#   Session MOU5498_20260426-1550: pickles already exist, loading.
# All MOU5498 sessions processed and saved.

# %% [markdown]
# Plot

# %%
fig = plt.figure(figsize=(cm2inch(12), cm2inch(8)), dpi=300, facecolor='w')
ax = fig.add_subplot(111)

plot_learning_curves_two_groups(
    mouse_metric_persession=ccw_turns_frechet_distances_per_session,
    ax=ax,
    group1_mice=SHAM_ANIMALS,
    group2_mice=LESION_ANIMALS,
    ylabel='CCW QTs Fréchet distance (cm)'
)

# %%
fig = plt.figure(figsize=(cm2inch(12), cm2inch(8)), dpi=300, facecolor='w')
ax = fig.add_subplot(111)

plot_learning_curves_two_groups(
    mouse_metric_persession=cw_turns_frechet_distances_per_session,
    ax=ax,
    group1_mice=SHAM_ANIMALS,
    group2_mice=LESION_ANIMALS,
    ylabel='CW QTs Fréchet distance (cm)'
)

# %% [markdown]
# ### QTs speed
# Data extraction

# %%
mouse_median_qt_maxspeed_persession = {mouse: [] for mouse in mice_to_analyse}
mouse_median_qt_meanspeed_persession = {mouse: [] for mouse in mice_to_analyse}

for mouse in mice_to_analyse:
    folder_path_mouse_to_analyse = os.path.join(path_to_data_folder, mouse)

    sessions_to_analyse = sorted([
        name for name in os.listdir(folder_path_mouse_to_analyse)
        if os.path.isdir(os.path.join(folder_path_mouse_to_analyse, name))
        and name.startswith('MOU')
    ])

    sessions_to_analyse = sessions_to_analyse[first_and_last_session_indexes[0]:first_and_last_session_indexes[1]]

    print(f'Mouse {mouse}. {len(sessions_to_analyse)} sessions')

    for session_index, session_to_analyse in enumerate(sessions_to_analyse):
        output_pickle_filename = f"{session_to_analyse}_basic_processing_output.pickle"
        output_pickle_filepath = os.path.join(
            folder_path_mouse_to_analyse,
            session_to_analyse,
            output_pickle_filename
        )

        if not os.path.exists(output_pickle_filepath):
            print(f'Pickle file missing for session {session_to_analyse}, skipping...')
            mouse_median_qt_maxspeed_persession[mouse].append([session_index + 1, np.nan])
            mouse_median_qt_meanspeed_persession[mouse].append([session_index + 1, np.nan])
            continue

        with open(output_pickle_filepath, 'rb') as file:
            session_data = pickle.load(file)

        # Tous les QTs filtrés, sans séparer CW / CCW
        qts = filter_qts(session_data["all_epochs"]["run_around_tower"])

        if len(qts) == 0:
            median_qt_maxspeed = np.nan
            median_qt_meanspeed = np.nan

        else:
            qt_maxspeeds = [qt[4]["epoch_maxspeed"] for qt in qts]
            qt_meanspeeds = [qt[4]["epoch_meanspeed"] for qt in qts]

            median_qt_maxspeed = np.nanmedian(qt_maxspeeds)
            median_qt_meanspeed = np.nanmedian(qt_meanspeeds)

        mouse_median_qt_maxspeed_persession[mouse].append([session_index + 1, median_qt_maxspeed])
        mouse_median_qt_meanspeed_persession[mouse].append([session_index + 1, median_qt_meanspeed])
# Out:
# Mouse MOUB6JRj748. 32 sessions
# Mouse MOUB6JRj749. 32 sessions
# Mouse MOUB6JRj750. 32 sessions
# Mouse MOUB6JRj751. 32 sessions
# Mouse MOUB6JRj752. 32 sessions
# Mouse MOU5465. 31 sessions
# Mouse MOU5468. 31 sessions
# Mouse MOU5500. 14 sessions
# Mouse MOU5501. 14 sessions
# Mouse MOUB6JRj753. 32 sessions
# Mouse MOUB6JRj755. 32 sessions
# Mouse MOUB6JRj756. 32 sessions
# Mouse MOU5289. 32 sessions
# Mouse MOU5291. 32 sessions
# Mouse MOU5413. 32 sessions
# Mouse MOU5415. 32 sessions
# Mouse MOU5471. 31 sessions
# Mouse MOU5496. 14 sessions
# Mouse MOU5498. 14 sessions

# %%
fig = plt.figure(figsize=(cm2inch(12), cm2inch(6)), dpi=300, facecolor='w')
ax = fig.add_subplot(111)

plot_learning_curves_two_groups(
    mouse_metric_persession=mouse_median_qt_maxspeed_persession,
    ax=ax,
    group1_mice=SHAM_ANIMALS,
    group2_mice=LESION_ANIMALS,
    ylabel='Median of QTs maximum speed (cm/s)',
    legend_loc=(0.01, 1.1)
)

# %%
fig = plt.figure(figsize=(cm2inch(12), cm2inch(6)), dpi=300, facecolor='w')
ax = fig.add_subplot(111)

plot_learning_curves_two_groups(
    mouse_metric_persession=mouse_median_qt_meanspeed_persession,
    ax=ax,
    group1_mice=SHAM_ANIMALS,
    group2_mice=LESION_ANIMALS,
    ylabel='Median of QTs mean speed (cm/s)',
    legend_loc=(0.01, 1.1)
)
