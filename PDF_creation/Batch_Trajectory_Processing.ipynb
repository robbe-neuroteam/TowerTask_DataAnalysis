# %% [markdown]
# # Notebook that does the processing of foraging session trajectories
#
# !! Part with PDF unfinished and so unusable !! (M, 22/02/2025)

# %% [markdown]
# ### Imports
# All functions are in behavior_analysis_functions.py

# %%
import os
import gc
import glob
import time
from processing_TowerCoordinates import *
from processing_session_trajectory import *
from functions_for_PDF import *

# %% [markdown]
# ### Get mice data
# Define the folder where your MOUXXX folder are, generate a list of MOUXXX folders and for each mice a list of sessions

# %%
# indicate where the data are
# path_to_data_folder is the path of the folder where you store your different mice.

path_to_data_folder = '/media/david/Maud_T5/Thesis/HarddriveDatas/Batch_22_temporaryfolder'

# If you want to process all the mice in your data folder
pattern_of_MOU_Folders = os.path.join(path_to_data_folder, "MOU*")
mice_to_process = [os.path.basename(path) for path in glob.glob(pattern_of_MOU_Folders)]
mice_to_process=sorted(mice_to_process)

# Print the number and the list of mice
print(f'Found {len(mice_to_process)} {"mice" if len(mice_to_process) > 1 else "mouse"} in the data folder: {", ".join(mice_to_process)}\n')


#If you want to process a subset of mice uncomment the line below and write your mice names
mice_to_process=["MOU5496","MOU5498","MOU5500","MOU5501",
                 "MOU5495","MOU5497","MOU5499","MOU5502","MOU5503"]

sessions_list = {}

for mouse in mice_to_process:

    mouse_folder = os.path.join(path_to_data_folder,mouse)
    sessions_list[mouse] = sorted([name for name in os.listdir(mouse_folder)
                           if os.path.isdir(os.path.join(mouse_folder, name))
                           and name.startswith('MOU')])
    nb_sessions = len(sessions_list[mouse])
    print(f'Hello, I\'m {mouse}! I have foraged for {nb_sessions} sessions:')
    print(sessions_list[mouse], '\n')
# Out:
# Found 9 mice in the data folder: MOU5495, MOU5496, MOU5497, MOU5498, MOU5499, MOU5500, MOU5501, MOU5502, MOU5503
#
# Hello, I'm MOU5496! I have foraged for 17 sessions:
# ['MOU5496_20260420-1016', 'MOU5496_20260420-1522', 'MOU5496_20260421-0959', 'MOU5496_20260421-1536', 'MOU5496_20260422-0958', 'MOU5496_20260422-1505', 'MOU5496_20260423-1008', 'MOU5496_20260423-1509', 'MOU5496_20260424-0957', 'MOU5496_20260424-1502', 'MOU5496_20260425-1017', 'MOU5496_20260425-1453', 'MOU5496_20260426-0959', 'MOU5496_20260426-1535', 'MOU5496_20260427-1039', 'MOU5496_20260427-1550', 'MOU5496_20260428-1022']
#
# Hello, I'm MOU5498! I have foraged for 17 sessions:
# ['MOU5498_20260420-1034', 'MOU5498_20260420-1541', 'MOU5498_20260421-1022', 'MOU5498_20260421-1557', 'MOU5498_20260422-1015', 'MOU5498_20260422-1520', 'MOU5498_20260423-1024', 'MOU5498_20260423-1524', 'MOU5498_20260424-1015', 'MOU5498_20260424-1519', 'MOU5498_20260425-1030', 'MOU5498_20260425-1508', 'MOU5498_20260426-1013', 'MOU5498_20260426-1550', 'MOU5498_20260427-1054', 'MOU5498_20260427-1604', 'MOU5498_20260428-1037']
#
# Hello, I'm MOU5500! I have foraged for 17 sessions:
# ['MOU5500_20260420-1117', 'MOU5500_20260420-1621', 'MOU5500_20260421-1106', 'MOU5500_20260421-1641', 'MOU5500_20260422-1055', 'MOU5500_20260422-1559', 'MOU5500_20260423-1100', 'MOU5500_20260423-1607', 'MOU5500_20260424-1053', 'MOU5500_20260424-1602', 'MOU5500_20260425-1100', 'MOU5500_20260425-1540', 'MOU5500_20260426-1121', 'MOU5500_20260426-1644', 'MOU5500_20260427-1151', 'MOU5500_20260427-1704', 'MOU5500_20260428-1130']
(f'Processing mouse {mouse}. There is/are {nb_sessions} sessions to process:')
    print(sessions_to_process, '\n')

    # Process each session
    for sessionindex, session_to_process in enumerate(sessions_to_process):
        print(f'Processing the trajectory of session {session_to_process}')

        if sessionindex==0: # We get the trapeze coordinates from the 1st session of 1 animal, and we will resuse them for the remaining sessions
            trapeze_width, towers_coordinates = get_trapeze_and_tower_data(mouse_folder, session_to_process)
            all_trapezes_coordinates_cm,towers_coordinates_cm= generate_trapeze_and_tower_coordinates(towers_coordinates, trapeze_width)

        # Define the pickle file path
        output_pickle_filename = f"{session_to_process}_basic_processing_output.pickle"
        output_pickle_filepath = os.path.join(mouse_folder, session_to_process, output_pickle_filename)

        # Check if the pickle file already exists
        if not overwrite and os.path.exists(output_pickle_filepath):
            # print(f'Pickle file already exists for session {session_to_process}, skipping processing.')
            continue  # Skip processing if the file exists and overwrite is False

        # Run the processing if file doesn't exist or overwrite is True
        output=process_trajectory(mouse_folder, session_to_process,all_trapezes_coordinates_cm,towers_coordinates_cm)
        if output is not None:
            bad_sessions.append(output)
        print('#########################\n')
# Out:
# Processing mouse MOU5496. There is/are 17 sessions to process:
# ['MOU5496_20260420-1016', 'MOU5496_20260420-1522', 'MOU5496_20260421-0959', 'MOU5496_20260421-1536', 'MOU5496_20260422-0958', 'MOU5496_20260422-1505', 'MOU5496_20260423-1008', 'MOU5496_20260423-1509', 'MOU5496_20260424-0957', 'MOU5496_20260424-1502', 'MOU5496_20260425-1017', 'MOU5496_20260425-1453', 'MOU5496_20260426-0959', 'MOU5496_20260426-1535', 'MOU5496_20260427-1039', 'MOU5496_20260427-1550', 'MOU5496_20260428-1022']
#
# Processing the trajectory of session MOU5496_20260420-1016
# Processing the trajectory of session MOU5496_20260420-1522
# Processing the trajectory of session MOU5496_20260421-0959
# Processing the trajectory of session MOU5496_20260421-1536
# Processing the trajectory of session MOU5496_20260422-0958
# Processing the trajectory of session MOU5496_20260422-1505
# Processing the trajectory of session MOU5496_20260423-1008
# Processing the trajectory of session MOU5496_20260423-1509
# Processing the trajectory of session MOU5496_20260424-0957
# Processing the trajectory of session MOU5496_20260424-1502
# Processing the trajectory of session MOU5496_20260425-1017
# Processing the trajectory of session MOU5496_20260425-1453
# Processing the trajectory of session MOU5496_20260426-0959
# Processing the trajectory of session MOU5496_20260426-1535
# Processing the trajectory of session MOU5496_20260427-1039
# Total time: 704.97 s.
# The total distance is: 174.64 m
# The average running speed is: 24.77 cm/s
# Processing run_between_towers epochs...
# Processing run_toward_tower epochs...
# Processing exploratory_run epochs...
# Processing immobility epochs...
# Session processing results saved to /media/david/Maud_T5/Thesis/HarddriveDatas/Batch_22_temporaryfolder/MOU5496/MOU5496_20260427-1039/MOU5496_20260427-1039_basic_processing_output.pickle
# #########################
#
# Processing the trajectory of session MOU5496_20260427-1550
# Total time: 704.98 s.
# The total distance is: 147.45 m
# The average running speed is: 20.92 cm/s
# Processing run_between_towers epochs...
# Processing run_toward_tower epochs...
# Processing exploratory_run epochs...
# Processing immobility epochs...
# Session processing results saved to /media/david/Maud_T5/Thesis/HarddriveDatas/Batch_22_temporaryfolder/MOU5496/MOU5496_20260427-1550/MOU5496_20260427-1550_basic_processing_output.pickle
# #########################
#
# Processing the trajectory of session MOU5496_20260428-1022
# Total time: 704.98 s.
# The total distance is: 172.53 m
# The average running speed is: 24.47 cm/s
# Processing run_between_towers epochs...
# Processing run_toward_tower epochs...
# Processing exploratory_run epochs...
# Processing immobility epochs...
# Session processing results saved to /media/david/Maud_T5/Thesis/HarddriveDatas/Batch_22_temporaryfolder/MOU5496/MOU5496_20260428-1022/MOU5496_20260428-1022_basic_processing_output.pickle
# #########################
#
# Processing mouse MOU5498. There is/are 17 sessions to process:
# ['MOU5498_20260420-1034', 'MOU5498_20260420-1541', 'MOU5498_20260421-1022', 'MOU5498_20260421-1557', 'MOU5498_20260422-1015', 'MOU5498_20260422-1520', 'MOU5498_20260423-1024', 'MOU5498_20260423-1524', 'MOU5498_20260424-1015', 'MOU5498_20260424-1519', 'MOU5498_20260425-1030', 'MOU5498_20260425-1508', 'MOU5498_20260426-1013', 'MOU5498_20260426-1550', 'MOU5498_20260427-1054', 'MOU5498_20260427-1604', 'MOU5498_20260428-1037']
#
# Processing the trajectory of session MOU5498_20260420-1034
cm/s
# Processing run_between_towers epochs...
# Processing run_toward_tower epochs...
# Processing exploratory_run epochs...
# Processing immobility epochs...
# Session processing results saved to /media/david/Maud_T5/Thesis/HarddriveDatas/Batch_22_temporaryfolder/MOU5502/MOU5502_20260426-1731/MOU5502_20260426-1731_basic_processing_output.pickle
# #########################
#
# Processing the trajectory of session MOU5502_20260427-1238
# Total time: 884.99 s.
# The total distance is: 117.89 m
# The average running speed is: 13.32 cm/s
# Processing run_between_towers epochs...
# Processing run_toward_tower epochs...
# Processing exploratory_run epochs...
# Processing immobility epochs...
# Session processing results saved to /media/david/Maud_T5/Thesis/HarddriveDatas/Batch_22_temporaryfolder/MOU5502/MOU5502_20260427-1238/MOU5502_20260427-1238_basic_processing_output.pickle
# #########################
#
# Processing the trajectory of session MOU5502_20260427-1749
# Total time: 884.99 s.
# The total distance is: 121.82 m
# The average running speed is: 13.76 cm/s
# Processing run_between_towers epochs...
# Processing run_toward_tower epochs...
# Processing exploratory_run epochs...
# Processing immobility epochs...
# Session processing results saved to /media/david/Maud_T5/Thesis/HarddriveDatas/Batch_22_temporaryfolder/MOU5502/MOU5502_20260427-1749/MOU5502_20260427-1749_basic_processing_output.pickle
# #########################
#
# Processing the trajectory of session MOU5502_20260428-1217
# Total time: 705.01 s.
# The total distance is: 97.27 m
# The average running speed is: 13.80 cm/s
# Processing run_between_towers epochs...
# Processing run_toward_tower epochs...
# Processing exploratory_run epochs...
# Processing immobility epochs...
# Session processing results saved to /media/david/Maud_T5/Thesis/HarddriveDatas/Batch_22_temporaryfolder/MOU5502/MOU5502_20260428-1217/MOU5502_20260428-1217_basic_processing_output.pickle
# #########################
#
# Processing mouse MOU5503. There is/are 5 sessions to process:
# ['MOU5503_20260426-1224', 'MOU5503_20260426-1750', 'MOU5503_20260427-1258', 'MOU5503_20260427-1823', 'MOU5503_20260428-1233']
#
# Processing the trajectory of session MOU5503_20260426-1224
# Processing the trajectory of session MOU5503_20260426-1750
# Total time: 884.99 s.
# The total distance is: 113.54 m
# The average running speed is: 12.83 cm/s
# Processing run_between_towers epochs...
# Processing run_toward_tower epochs...
# Processing exploratory_run epochs...
# Processing immobility epochs...
# Session processing results saved to /media/david/Maud_T5/Thesis/HarddriveDatas/Batch_22_temporaryfolder/MOU5503/MOU5503_20260426-1750/MOU5503_20260426-1750_basic_processing_output.pickle
# #########################
#
# Processing the trajectory of session MOU5503_20260427-1258
# Total time: 884.99 s.
# The total distance is: 117.36 m
# The average running speed is: 13.26 cm/s
# Processing run_between_towers epochs...
# Processing run_toward_tower epochs...
# Processing exploratory_run epochs...
# Processing immobility epochs...
# Session processing results saved to /media/david/Maud_T5/Thesis/HarddriveDatas/Batch_22_temporaryfolder/MOU5503/MOU5503_20260427-1258/MOU5503_20260427-1258_basic_processing_output.pickle
# #########################
#
# Processing the trajectory of session MOU5503_20260427-1823
# Total time: 884.99 s.
# The total distance is: 108.09 m
# The average running speed is: 12.21 cm/s
# Processing run_between_towers epochs...
# Processing run_toward_tower epochs...
# Processing exploratory_run epochs...
# Processing immobility epochs...
# Session processing results saved to /media/david/Maud_T5/Thesis/HarddriveDatas/Batch_22_temporaryfolder/MOU5503/MOU5503_20260427-1823/MOU5503_20260427-1823_basic_processing_output.pickle
# #########################
#
# Processing the trajectory of session MOU5503_20260428-1233
# Total time: 704.98 s.
# The total distance is: 88.03 m
# The average running speed is: 12.49 cm/s
# Processing run_between_towers epochs...
# Processing run_toward_tower epochs...
# Processing exploratory_run epochs...
# Processing immobility epochs...
# Session processing results saved to /media/david/Maud_T5/Thesis/HarddriveDatas/Batch_22_temporaryfolder/MOU5503/MOU5503_20260428-1233/MOU5503_20260428-1233_basic_processing_output.pickle
# #########################

# %% [markdown]
# ## Create PDFs of all sessions
#
# Here you can choose to create a PDF (or not) in order to visualize the datas of all sessions.
#
# You can create 2 independant PDF : one containing all main metrics of different types of runs ; one containing the raster plot of visits and 2 distribution charts (rewarded visits duration, and number of runs in rewarded visits).
#
# You can set the variables containing 'overwrite' to True if you want to recreate the PDF from the beginning (and therefore processing all sessions) or to add only new sessions that have not been plotted yet. You also have the possibility to generate only one PDF out of the two possible.

# %%
---------------------------------------

# Choose if you want to generate and/or overwrite the metrics PDF
generate_pdf_metrics = True
overwrite_pdf_metrics = False
output_path_metrics = f"{mouse_folder}/{mouse}_metrics_figures.pdf"

# Choose if you want to generate and/or overwrite the visits PDF
generate_pdf_visits = True
overwrite_pdf_visits = False 
output_path_visits = f"{mouse_folder}/{mouse}_visits_figures.pdf"

# Processing of sessions to create PDFs

for mouse in mice_to_process:

    print(f"Creating {mouse} PDFs\n")    
    mouse_folder = os.path.join(path_to_data_folder, mouse) 
    sessions_list = sorted([name for name in os.listdir(mouse_folder)
                if os.path.isdir(os.path.join(mouse_folder, name))
                and name.startswith('MOU')])
    
    if generate_pdf_metrics:
        print("Metrics PDF generation ongoing...\n")
        make_pdf_metrics(mouse_folder, sessions_list, mouse, output_path_metrics, overwrite=overwrite_pdf_metrics)

    if generate_pdf_visits: 
        print("\nVisits PDF generation ongoing...")
        make_pdf_visits(mouse_folder, sessions_list, mouse, output_path_visits, overwrite=overwrite_pdf_visits)
# Out:
#   Cell In[4], line 1
#     ---------------------------------------
#                                            ^
# SyntaxError: invalid syntax
